# %%
# # code required to run on a fresh install or in google colab
# ! git clone https://github.com/CPMpy/XCP-explain.git /tmp/XCP-explain
# ! cd XCP-explain && git checkout ecai24
# ! pip install -r XCP-explain/requirements.txt
# ! pip install cpmpy

# # add XCP-explain to the Python path
# import sys
# root = "/tmp/XCP-explain"
# if root not in sys.path:
#     sys.path.insert(0, root)
root= "."

# %%
# %load_ext autoreload
# %autoreload 2
"""
    Some imports used throughout the notebook
"""
import time
import os
from visualize import *

from cpmpy.transformations.normalize import toplevel_list
from factory import *
from read_data import get_data
from IPython.display import clear_output


import numpy as np
np.set_printoptions(linewidth=90)
# preload solvers
from cpmpy import SolverLookup
names = SolverLookup.solvernames()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-06-03

# %% [markdown]
# ## Hands-on causal explanations
#
# In this notebook, you will get experience with computing causal explanations.
#
# We focus on explaining unsatisfiability by means of extracting a MUS.
#
#
#
# <img src="img/mus.png" width="20%" align="right" style="margin:50px;">
#
# Trim model to minimal set of constraints
#
# ... minimize cognitive burden for user

# %%
instance = os.path.join(root,"Benchmarks/CustomInstance.txt")
data = get_data(instance)
factory = NurseSchedulingFactory(data)

# %% [markdown]
# Let's have a look at the instance and its (optimal) solution.

# %%
data.staff[["name", "MaxShifts","MaxWeekends"]]
# Out:
#         name  MaxShifts  MaxWeekends
# 0      Megan  E=14|L=14            2
# 1  Katherine  E=14|L=14            1
# 2     Robert  E=14|L=14            2
# 3   Jonathan   E=14|L=0            1
# 4    William   E=0|L=14            1
# 5    Richard  E=14|L=14            2
# 6    Kristen  E=14|L=14            1
# 7      Kevin  E=14|L=14            2
# 8     Thomas  E=14|L=14            1

# %%
print(f"Planning for {data.horizon} days")
# Out:
# Planning for 14 days

# %%
model, nurse_view = factory.get_optimization_model()
assert model.solve(solver="ortools") # you can try different solvers here!


print(model.status())
print("Total penalty:", model.objective_value())
visualize(nurse_view.value(), factory)
# Out:
# ExitStatus.OPTIMAL (0.12648 seconds)
# Total penalty: 1303
# <style type="text/css">
# #T_ee3be .data {
#   text-align: center;
# }
# #T_ee3be .col_heading {
#   text-align: center;
# }
# #T_ee3be .col7 {
#   border-left: 2px solid black;
# }
# #T_ee3be_row0_col0, #T_ee3be_row0_col12, #T_ee3be_row1_col3, #T_ee3be_row1_col4, #T_ee3be_row1_col7, #T_ee3be_row1_col8, #T_ee3be_row1_col9, #T_ee3be_row1_col10, #T_ee3be_row1_col11, #T_ee3be_row1_col12, #T_ee3be_row1_col13, #T_ee3be_row2_col3, #T_ee3be_row2_col4, #T_ee3be_row2_col5, #T_ee3be_row2_col9, #T_ee3be_row2_col10, #T_ee3be_row2_col11, #T_ee3be_row2_col12, #T_ee3be_row2_col13, #T_ee3be_row3_col0, #T_ee3be_row3_col1, #T_ee3be_row3_col2, #T_ee3be_row3_col3, #T_ee3be_row3_col8, #T_ee3be_row3_col9, #T_ee3be_row3_col10, #T_ee3be_row3_col13, #T_ee3be_row7_col0, #T_ee3be_row7_col1, #T_ee3be_row7_col5, #T_ee3be_row7_col6, #T_ee3be_row7_col7, #T_ee3be_row7_col8, #T_ee3be_row7_col12, #T_ee3be_row8_col1, #T_ee3be_row8_col2, #T_ee3be_row8_col3, #T_ee3be_row8_col4, #T_ee3be_row8_col7, #T_ee3be_row8_col8, #T_ee3be_row8_col9, #T_ee3be_row8_col10 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_ee3be_row0_col1, #T_ee3be_row0_col2, #T_ee3be_row0_col5, #T_ee3be_row0_col6, #T_ee3be_row0_col7, #T_ee3be_row0_col8, #T_ee3be_row0_col9, #T_ee3be_row0_col13, #T_ee3be_row1_col0, #T_ee3be_row2_col0, #T_ee3be_row2_col6, #T_ee3be_row4_col2, #T_ee3be_row4_col3, #T_ee3be_row4_col4, #T_ee3be_row4_col7, #T_ee3be_row4_col8, #T_ee3be_row4_col12, #T_ee3be_row4_col13, #T_ee3be_row5_col1, #T_ee3be_row5_col2, #T_ee3be_row5_col3, #T_ee3be_row5_col4, #T_ee3be_row5_col5, #T_ee3be_row5_col8, #T_ee3be_row5_col9, #T_ee3be_row5_col10, #T_ee3be_row5_col11, #T_ee3be_row5_col12, #T_ee3be_row6_col0, #T_ee3be_row6_col1, #T_ee3be_row6_col2, #T_ee3be_row6_col3, #T_ee3be_row6_col4, #T_ee3be_row6_col5, #T_ee3be_row6_col6, #T_ee3be_row6_col10, #T_ee3be_row6_col11, #T_ee3be_row7_col2, #T_ee3be_row7_col9, #T_ee3be_row7_col13, #T_ee3be_row8_col11, #T_ee3be_row8_col12, #T_ee3be_row8_col13 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
# }
# #T_ee3be_row0_col3, #T_ee3be_row0_col4, #T_ee3be_row0_col10, #T_ee3be_row0_col11, #T_ee3be_row1_col1, #T_ee3be_row1_col2, #T_ee3be_row1_col5, #T_ee3be_row1_col6, #T_ee3be_row2_col1, #T_ee3be_row2_col2, #T_ee3be_row2_col7, #T_ee3be_row2_col8, #T_ee3be_row3_col4, #T_ee3be_row3_col5, #T_ee3be_row3_col6, #T_ee3be_row3_col7, #T_ee3be_row3_col11, #T_ee3be_row3_col12, #T_ee3be_row4_col0, #T_ee3be_row4_col1, #T_ee3be_row4_col5, #T_ee3be_row4_col6, #T_ee3be_row4_col9, #T_ee3be_row4_col10, #T_ee3be_row4_col11, #T_ee3be_row5_col0, #T_ee3be_row5_col6, #T_ee3be_row5_col7, #T_ee3be_row5_col13, #T_ee3be_row6_col7, #T_ee3be_row6_col8, #T_ee3be_row6_col9, #T_ee3be_row6_col12, #T_ee3be_row6_col13, #T_ee3be_row7_col3, #T_ee3be_row7_col4, #T_ee3be_row7_col10, #T_ee3be_row7_col11, #T_ee3be_row8_col0, #T_ee3be_row8_col5, #T_ee3be_row8_col6 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# </style>
# <table id="T_ee3be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee3be_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_ee3be_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_ee3be_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_ee3be_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ee3be_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_ee3be_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_ee3be_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_ee3be_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_ee3be_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_ee3be_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_ee3be_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_ee3be_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_ee3be_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_ee3be_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_ee3be_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_ee3be_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_ee3be_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_ee3be_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_ee3be_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_ee3be_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_ee3be_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee3be_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_ee3be_row0_col0" class="data row0 col0" >E</td>
#       <td id="T_ee3be_row0_col1" class="data row0 col1" >L</td>
#       <td id="T_ee3be_row0_col2" class="data row0 col2" >L</td>
#       <td id="T_ee3be_row0_col3" class="data row0 col3" >F</td>
#       <td id="T_ee3be_row0_col4" class="data row0 col4" >F</td>
#       <td id="T_ee3be_row0_col5" class="data row0 col5" >L</td>
#       <td id="T_ee3be_row0_col6" class="data row0 col6" >L</td>
#       <td id="T_ee3be_row0_col7" class="data row0 col7" >L</td>
#       <td id="T_ee3be_row0_col8" class="data row0 col8" >L</td>
#       <td id="T_ee3be_row0_col9" class="data row0 col9" >L</td>
#       <td id="T_ee3be_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_ee3be_row0_col11" class="data row0 col11" >F</td>
#       <td id="T_ee3be_row0_col12" class="data row0 col12" >E</td>
#       <td id="T_ee3be_row0_col13" class="data row0 col13" >L</td>
#       <td id="T_ee3be_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_ee3be_row0_col15" class="data row0 col15" >8</td>
#       <td id="T_ee3be_row0_col16" class="data row0 col16" >4800</td>
#     </tr>
#     <tr>
#       <th id="T_ee3be_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_ee3be_row1_col0" class="data row1 col0" >L</td>
#       <td id="T_ee3be_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_ee3be_row1_col2" class="data row1 col2" >F</td>
#       <td id="T_ee3be_row1_col3" class="data row1 col3" >E</td>
#       <td id="T_ee3be_row1_col4" class="data row1 col4" >E</td>
#       <td id="T_ee3be_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_ee3be_row1_col6" class="data row1 col6" >F</td>
#       <td id="T_ee3be_row1_col7" class="data row1 col7" >E</td>
#       <td id="T_ee3be_row1_col8" class="data row1 col8" >E</td>
#       <td id="T_ee3be_row1_col9" class="data row1 col9" >E</td>
#       <td id="T_ee3be_row1_col10" class="data row1 col10" >E</td>
#       <td id="T_ee3be_row1_col11" class="data row1 col11" >E</td>
#       <td id="T_ee3be_row1_col12" class="data row1 col12" >E</td>
#       <td id="T_ee3be_row1_col13" class="data row1 col13" >E</td>
#       <td id="T_ee3be_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_ee3be_row1_col15" class="data row1 col15" >1</td>
#       <td id="T_ee3be_row1_col16" class="data row1 col16" >4800</td>
#     </tr>
#     <tr>
#       <

# %%
requests, _ = factory.shift_on_requests(formulation="hard")

denied_requests = [req for req in requests if req.value() is False]
print("The following requests were denied:")
for req in denied_requests:
    print("-", req)

visualize_constraints(denied_requests, nurse_view, factory, do_clear=False)
# Out:
# The following requests were denied:
# - Robert requests to work shift E on Tue 2
# - William requests to work shift L on Sat 1
# - William requests to work shift L on Sun 1
# <style type="text/css">
# #T_c2cbc .data {
#   text-align: center;
# }
# #T_c2cbc .col_heading {
#   text-align: center;
# }
# #T_c2cbc .col7 {
#   border-left: 2px solid black;
# }
# #T_c2cbc_row0_col0, #T_c2cbc_row0_col12, #T_c2cbc_row1_col3, #T_c2cbc_row1_col4, #T_c2cbc_row1_col7, #T_c2cbc_row1_col8, #T_c2cbc_row1_col9, #T_c2cbc_row1_col10, #T_c2cbc_row1_col11, #T_c2cbc_row1_col12, #T_c2cbc_row1_col13, #T_c2cbc_row2_col3, #T_c2cbc_row2_col4, #T_c2cbc_row2_col5, #T_c2cbc_row2_col9, #T_c2cbc_row2_col10, #T_c2cbc_row2_col11, #T_c2cbc_row2_col12, #T_c2cbc_row2_col13, #T_c2cbc_row3_col0, #T_c2cbc_row3_col1, #T_c2cbc_row3_col2, #T_c2cbc_row3_col3, #T_c2cbc_row3_col8, #T_c2cbc_row3_col9, #T_c2cbc_row3_col10, #T_c2cbc_row3_col13, #T_c2cbc_row7_col0, #T_c2cbc_row7_col1, #T_c2cbc_row7_col5, #T_c2cbc_row7_col6, #T_c2cbc_row7_col7, #T_c2cbc_row7_col8, #T_c2cbc_row7_col12, #T_c2cbc_row8_col1, #T_c2cbc_row8_col2, #T_c2cbc_row8_col3, #T_c2cbc_row8_col4, #T_c2cbc_row8_col7, #T_c2cbc_row8_col8, #T_c2cbc_row8_col9, #T_c2cbc_row8_col10 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_c2cbc_row0_col1, #T_c2cbc_row0_col2, #T_c2cbc_row0_col5, #T_c2cbc_row0_col6, #T_c2cbc_row0_col7, #T_c2cbc_row0_col8, #T_c2cbc_row0_col9, #T_c2cbc_row0_col13, #T_c2cbc_row1_col0, #T_c2cbc_row2_col0, #T_c2cbc_row2_col6, #T_c2cbc_row4_col2, #T_c2cbc_row4_col3, #T_c2cbc_row4_col4, #T_c2cbc_row4_col7, #T_c2cbc_row4_col8, #T_c2cbc_row4_col12, #T_c2cbc_row4_col13, #T_c2cbc_row5_col1, #T_c2cbc_row5_col2, #T_c2cbc_row5_col3, #T_c2cbc_row5_col4, #T_c2cbc_row5_col5, #T_c2cbc_row5_col8, #T_c2cbc_row5_col9, #T_c2cbc_row5_col10, #T_c2cbc_row5_col11, #T_c2cbc_row5_col12, #T_c2cbc_row6_col0, #T_c2cbc_row6_col1, #T_c2cbc_row6_col2, #T_c2cbc_row6_col3, #T_c2cbc_row6_col4, #T_c2cbc_row6_col5, #T_c2cbc_row6_col6, #T_c2cbc_row6_col10, #T_c2cbc_row6_col11, #T_c2cbc_row7_col2, #T_c2cbc_row7_col9, #T_c2cbc_row7_col13, #T_c2cbc_row8_col11, #T_c2cbc_row8_col12, #T_c2cbc_row8_col13 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
# }
# #T_c2cbc_row0_col3, #T_c2cbc_row0_col4, #T_c2cbc_row0_col10, #T_c2cbc_row0_col11, #T_c2cbc_row1_col1, #T_c2cbc_row1_col2, #T_c2cbc_row1_col5, #T_c2cbc_row1_col6, #T_c2cbc_row2_col1, #T_c2cbc_row2_col2, #T_c2cbc_row2_col7, #T_c2cbc_row3_col4, #T_c2cbc_row3_col5, #T_c2cbc_row3_col6, #T_c2cbc_row3_col7, #T_c2cbc_row3_col11, #T_c2cbc_row3_col12, #T_c2cbc_row4_col0, #T_c2cbc_row4_col1, #T_c2cbc_row4_col9, #T_c2cbc_row4_col10, #T_c2cbc_row4_col11, #T_c2cbc_row5_col0, #T_c2cbc_row5_col6, #T_c2cbc_row5_col7, #T_c2cbc_row5_col13, #T_c2cbc_row6_col7, #T_c2cbc_row6_col8, #T_c2cbc_row6_col9, #T_c2cbc_row6_col12, #T_c2cbc_row6_col13, #T_c2cbc_row7_col3, #T_c2cbc_row7_col4, #T_c2cbc_row7_col10, #T_c2cbc_row7_col11, #T_c2cbc_row8_col0, #T_c2cbc_row8_col5, #T_c2cbc_row8_col6 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# #T_c2cbc_row2_col8, #T_c2cbc_row4_col5, #T_c2cbc_row4_col6 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   background-color: rgb(183, 119, 41);
# }
# </style>
# <table id="T_c2cbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2cbc_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_c2cbc_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_c2cbc_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_c2cbc_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_c2cbc_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_c2cbc_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_c2cbc_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_c2cbc_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_c2cbc_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_c2cbc_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_c2cbc_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_c2cbc_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_c2cbc_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_c2cbc_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_c2cbc_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_c2cbc_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_c2cbc_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_c2cbc_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_c2cbc_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_c2cbc_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_c2cbc_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2cbc_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_c2cbc_row0_col0" class="data row0 col0" >E</td>
#       <td id="T_c2cbc_row0_col1" class="data row0 col1" >L</td>
#       <td id="T_c2cbc_row0_col2" class="data row0 col2" >L</td>
#       <td id="T_c2cbc_row0_col3" class="data row0 col3" >F</td>
#       <td id="T_c2cbc_row0_col4" class="data row0 col4" >F</td>
#       <td id="T_c2cbc_row0_col5" class="data row0 col5" >L</td>
#       <td id="T_c2cbc_row0_col6" class="data row0 col6" >L</td>
#       <td id="T_c2cbc_row0_col7" class="data row0 col7" >L</td>
#       <td id="T_c2cbc_row0_col8" class="data row0 col8" >L</td>
#       <td id="T_c2cbc_row0_col9" class="data row0 col9" >L</td>
#       <td id="T_c2cbc_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_c2cbc_row0_col11" class="data row0 col11" >F</td>
#       <td id="T_c2cbc_row0_col12" class="data row0 col12" >E</td>
#       <td id="T_c2cbc_row0_col13" class="data row0 col13" >L</td>
#       <td id="T_c2cbc_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_c2cbc_row0_col15" class="data row0 col15" >8</td>
#       <td id="T_c2cbc_row0_col16" class="data row0 col16" >4800</td>
#     </tr>
#     <tr>
#       <th id="T_c2cbc_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_c2cbc_row1_col0" class="data row1 col0" >L</td>
#       <td id="T_c2cbc_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_c2cbc_row1_col2" class="data row1 col2" >F</td>
#       <td id="T_c2cbc_row1_col3" class="data row1 col3" >E</td>
#       <td id="T_c2cbc_row1_col4" class="data row1 col4" >E</td>
#       <td id="T_c2cbc_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_c2cbc_row1_col6" class="data row1 col6" >F</td>
#       <td id="T_c2cbc_row1_col7" class="data row1 col7" >E</td>
#       <td id="T_c2cbc_row1_col8" class="data row1 col8" >E</td>
#       <td id="T_c2cbc_row1_col9" class="data row1 col9" >E</td>
#       <td id="T_c2cbc_row1_col10" class="data row1 col10" >E</td>
#       <td id="T_c2cbc_row1_col11" class="data row1 col11" >E</td>
#       <td id="T_c2cbc_row1_col12" class="data row1 col12" >E</td>
#       <td id="T_c2cbc_row1_col13" class="data row1 col13" >E</td>
#       <td id="T_c2cbc_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_c2cbc_row1_col15" class="data row1 col

# %%
# try it yourself!

# requests, _ = factory.shift_off_requests(formulation="hard")
# cover_constraints, _ = factory.cover(formulation="hard")

# TODO: find out which are not satisfied, and visualize!

# %% [markdown]
# ## Deductive explanations
#
# In the remainder of this notebook, we will explore different ways of explaining unsatisfiabily of the instance.

# %%
model, nurse_view = factory.get_decision_model()
model.solve()
# Out:
# False

# %%
from cpmpy.tools.explain import mus

t0 = time.time()
conflict = mus(model.constraints) # try different solvers here!
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 3 in 1.11s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - William should work at most 1 weekends
# - William requests to work shift L on Sat 2
# - William requests to work shift L on Sat 1
# <style type="text/css">
# #T_e8db0 .data {
#   text-align: center;
# }
# #T_e8db0 .col_heading {
#   text-align: center;
# }
# #T_e8db0 .col7 {
#   border-left: 2px solid black;
# }
# #T_e8db0_row0_col0, #T_e8db0_row0_col1, #T_e8db0_row0_col2, #T_e8db0_row0_col3, #T_e8db0_row0_col4, #T_e8db0_row0_col5, #T_e8db0_row0_col6, #T_e8db0_row0_col7, #T_e8db0_row0_col8, #T_e8db0_row0_col9, #T_e8db0_row0_col10, #T_e8db0_row0_col11, #T_e8db0_row0_col12, #T_e8db0_row0_col13, #T_e8db0_row1_col0, #T_e8db0_row1_col1, #T_e8db0_row1_col2, #T_e8db0_row1_col3, #T_e8db0_row1_col4, #T_e8db0_row1_col5, #T_e8db0_row1_col6, #T_e8db0_row1_col7, #T_e8db0_row1_col8, #T_e8db0_row1_col9, #T_e8db0_row1_col10, #T_e8db0_row1_col11, #T_e8db0_row1_col12, #T_e8db0_row1_col13, #T_e8db0_row2_col0, #T_e8db0_row2_col1, #T_e8db0_row2_col2, #T_e8db0_row2_col3, #T_e8db0_row2_col4, #T_e8db0_row2_col5, #T_e8db0_row2_col6, #T_e8db0_row2_col7, #T_e8db0_row2_col8, #T_e8db0_row2_col9, #T_e8db0_row2_col10, #T_e8db0_row2_col11, #T_e8db0_row2_col12, #T_e8db0_row2_col13, #T_e8db0_row3_col0, #T_e8db0_row3_col1, #T_e8db0_row3_col2, #T_e8db0_row3_col3, #T_e8db0_row3_col4, #T_e8db0_row3_col5, #T_e8db0_row3_col6, #T_e8db0_row3_col7, #T_e8db0_row3_col8, #T_e8db0_row3_col9, #T_e8db0_row3_col10, #T_e8db0_row3_col11, #T_e8db0_row3_col12, #T_e8db0_row3_col13, #T_e8db0_row4_col0, #T_e8db0_row4_col1, #T_e8db0_row4_col2, #T_e8db0_row4_col3, #T_e8db0_row4_col4, #T_e8db0_row4_col7, #T_e8db0_row4_col8, #T_e8db0_row4_col9, #T_e8db0_row4_col10, #T_e8db0_row4_col11, #T_e8db0_row5_col0, #T_e8db0_row5_col1, #T_e8db0_row5_col2, #T_e8db0_row5_col3, #T_e8db0_row5_col4, #T_e8db0_row5_col5, #T_e8db0_row5_col6, #T_e8db0_row5_col7, #T_e8db0_row5_col8, #T_e8db0_row5_col9, #T_e8db0_row5_col10, #T_e8db0_row5_col11, #T_e8db0_row5_col12, #T_e8db0_row5_col13, #T_e8db0_row6_col0, #T_e8db0_row6_col1, #T_e8db0_row6_col2, #T_e8db0_row6_col3, #T_e8db0_row6_col4, #T_e8db0_row6_col5, #T_e8db0_row6_col6, #T_e8db0_row6_col7, #T_e8db0_row6_col8, #T_e8db0_row6_col9, #T_e8db0_row6_col10, #T_e8db0_row6_col11, #T_e8db0_row6_col12, #T_e8db0_row6_col13, #T_e8db0_row7_col0, #T_e8db0_row7_col1, #T_e8db0_row7_col2, #T_e8db0_row7_col3, #T_e8db0_row7_col4, #T_e8db0_row7_col5, #T_e8db0_row7_col6, #T_e8db0_row7_col7, #T_e8db0_row7_col8, #T_e8db0_row7_col9, #T_e8db0_row7_col10, #T_e8db0_row7_col11, #T_e8db0_row7_col12, #T_e8db0_row7_col13, #T_e8db0_row8_col0, #T_e8db0_row8_col1, #T_e8db0_row8_col2, #T_e8db0_row8_col3, #T_e8db0_row8_col4, #T_e8db0_row8_col5, #T_e8db0_row8_col6, #T_e8db0_row8_col7, #T_e8db0_row8_col8, #T_e8db0_row8_col9, #T_e8db0_row8_col10, #T_e8db0_row8_col11, #T_e8db0_row8_col12, #T_e8db0_row8_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_e8db0_row4_col5, #T_e8db0_row4_col12 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   background-color: rgb(183, 119, 41);
# }
# #T_e8db0_row4_col6, #T_e8db0_row4_col13 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# </style>
# <table id="T_e8db0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8db0_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_e8db0_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_e8db0_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_e8db0_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e8db0_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_e8db0_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_e8db0_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_e8db0_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_e8db0_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_e8db0_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_e8db0_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_e8db0_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_e8db0_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_e8db0_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_e8db0_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_e8db0_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_e8db0_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_e8db0_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_e8db0_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_e8db0_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_e8db0_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8db0_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_e8db0_row0_col0" class="data row0 col0" ></td>
#       <td id="T_e8db0_row0_col1" class="data row0 col1" ></td>
#       <td id="T_e8db0_row0_col2" class="data row0 col2" ></td>
#       <td id="T_e8db0_row0_col3" class="data row0 col3" ></td>
#       <td id="T_e8db0_row0_col4" class="data row0 col4" ></td>
#       <td id="T_e8db0_row0_col5" class="data row0 col5" ></td>
#       <td id="T_e8db0_row0_col6" class="data row0 col6" ></td>
#       <td id="T_e8db0_row0_col7" class="data row0 col7" ></td>
#       <td id="T_e8db0_row0_col8" class="data row0 col8" ></td>
#       <td id="T_e8db0_row0_col9" class="data row0 col9" ></td>
#       <td id="T_e8db0_row0_col10" class="data row0 col10" ></td>
#       <td id="T_e8db0_row0_col11" class="data row0 col11" ></td>
#       <td id="T_e8db0_row0_col12" class="data row0 col12" ></td>
#       <td id="T_e8db0_row0_col13" class="data row0 col13" ></td>
#       <td id="T_e8db0_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_e8db0_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_e8db0_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e8db0_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_e8db0_row1_col0" class="data row1 col0" ></td>
#       <td id="T_e8db0_row1_col1" class="data row1 col1" ></td>
#       <td id="T_e8db0_row1_col2" class="data row1 col2" ></td>
#       <td id="T_e8db0_row1_col3" class="data row1 col3" ></td>
#       <td id="T_e8db0_row1_col4" class="data row1 col4" ></td>
#       <td id="T_e8db0_row1_col5" class="data row1 col5" ></td>
#       <td id="T_e8db0_row1_col6" class="data row1 col6" ></td>
#       <td id="T_e8db0_row1_col7" class="data row1 col7" ></td>
#       <td id="T_e8db0_row1_col8" class="data row1 col8" ></td>
#       <td id="T_e8db0_row1_col9" class="data row1 col9" ></td>
#       <td id="T_e8db0_row1_col10" class="data row1 col10" ></td>
#       <td id="T_e8db0_row1_col11" class="data row1 col11" ></td>
#       <td id="T_e8db0_row1_col12" class="data row1 col12" ></td>
#       <td id="T_e8db0_row1_col13" class="data row1 col13" ></td>
#       <td id="T_e8db0_row1_col14" class="data row1

# %% [markdown]
# Now, let's influence the MUS we would like to find.
#
# We can chose from QuickXplain [1] or Optimal MUS (OUS) [2]
#
# **QuickXplain** takes as input a total ordering of constraints, and returns a lexicographically minimal MUS.
# The algorithm is build up as a divide-and-conquer approach, and therefore has a good average complexity.
#
# **OUS** takes as input a weight for each constraint, and finds a **optimal** MUS. While this optimality guarantee is sometimes required, it comes at a penalty of longer computation times, as you will notice here!

# %%
# QuickXplain first
from cpmpy.tools.explain import quickxplain


def get_weight(cons):
    if "William" in str(cons): # Find a different MUS than the previous
        return 2 
    return 1

ordered = sorted(model.constraints, key=get_weight)
conflict = quickxplain(ordered)
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 13 in 9.24s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Richard can work at most 5 days before having a day off
# - Katherine has a day off on Tue 1
# - Robert has a day off on Wed 1
# - Thomas has a day off on Mon 1
# - Katherine should have at least 2 consecutive days off
# - Richard should have at least 2 consecutive days off
# - Richard should have at least 2 consecutive days off
# - Richard requests to work shift L on Thu 1
# - Richard requests to work shift L on Sat 1
# - Shift E on Mon 1 must be covered by 4 nurses out of 9
# - Shift L on Mon 1 must be covered by 3 nurses out of 9
# - Shift E on Wed 1 must be covered by 3 nurses out of 9
# - Shift L on Wed 1 must be covered by 5 nurses out of 9
# <style type="text/css">
# #T_a5f48 .data {
#   text-align: center;
# }
# #T_a5f48 .col_heading {
#   text-align: center;
# }
# #T_a5f48 .col7 {
#   border-left: 2px solid black;
# }
# #T_a5f48_row0_col0, #T_a5f48_row0_col2 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row0_col1, #T_a5f48_row0_col3, #T_a5f48_row0_col4, #T_a5f48_row0_col5, #T_a5f48_row0_col6, #T_a5f48_row0_col7, #T_a5f48_row0_col8, #T_a5f48_row0_col9, #T_a5f48_row0_col10, #T_a5f48_row0_col11, #T_a5f48_row0_col12, #T_a5f48_row0_col13, #T_a5f48_row1_col3, #T_a5f48_row1_col4, #T_a5f48_row1_col5, #T_a5f48_row1_col6, #T_a5f48_row1_col7, #T_a5f48_row1_col8, #T_a5f48_row1_col9, #T_a5f48_row1_col10, #T_a5f48_row1_col11, #T_a5f48_row1_col12, #T_a5f48_row1_col13, #T_a5f48_row2_col1, #T_a5f48_row2_col3, #T_a5f48_row2_col4, #T_a5f48_row2_col5, #T_a5f48_row2_col6, #T_a5f48_row2_col7, #T_a5f48_row2_col8, #T_a5f48_row2_col9, #T_a5f48_row2_col10, #T_a5f48_row2_col11, #T_a5f48_row2_col12, #T_a5f48_row2_col13, #T_a5f48_row3_col1, #T_a5f48_row3_col3, #T_a5f48_row3_col4, #T_a5f48_row3_col5, #T_a5f48_row3_col6, #T_a5f48_row3_col7, #T_a5f48_row3_col8, #T_a5f48_row3_col9, #T_a5f48_row3_col10, #T_a5f48_row3_col11, #T_a5f48_row3_col12, #T_a5f48_row3_col13, #T_a5f48_row4_col1, #T_a5f48_row4_col3, #T_a5f48_row4_col4, #T_a5f48_row4_col5, #T_a5f48_row4_col6, #T_a5f48_row4_col7, #T_a5f48_row4_col8, #T_a5f48_row4_col9, #T_a5f48_row4_col10, #T_a5f48_row4_col11, #T_a5f48_row4_col12, #T_a5f48_row4_col13, #T_a5f48_row5_col6, #T_a5f48_row5_col7, #T_a5f48_row5_col8, #T_a5f48_row5_col9, #T_a5f48_row5_col10, #T_a5f48_row5_col11, #T_a5f48_row5_col12, #T_a5f48_row5_col13, #T_a5f48_row6_col1, #T_a5f48_row6_col3, #T_a5f48_row6_col4, #T_a5f48_row6_col5, #T_a5f48_row6_col6, #T_a5f48_row6_col7, #T_a5f48_row6_col8, #T_a5f48_row6_col9, #T_a5f48_row6_col10, #T_a5f48_row6_col11, #T_a5f48_row6_col12, #T_a5f48_row6_col13, #T_a5f48_row7_col1, #T_a5f48_row7_col3, #T_a5f48_row7_col4, #T_a5f48_row7_col5, #T_a5f48_row7_col6, #T_a5f48_row7_col7, #T_a5f48_row7_col8, #T_a5f48_row7_col9, #T_a5f48_row7_col10, #T_a5f48_row7_col11, #T_a5f48_row7_col12, #T_a5f48_row7_col13, #T_a5f48_row8_col1, #T_a5f48_row8_col3, #T_a5f48_row8_col4, #T_a5f48_row8_col5, #T_a5f48_row8_col6, #T_a5f48_row8_col7, #T_a5f48_row8_col8, #T_a5f48_row8_col9, #T_a5f48_row8_col10, #T_a5f48_row8_col11, #T_a5f48_row8_col12, #T_a5f48_row8_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_a5f48_row1_col0, #T_a5f48_row2_col0, #T_a5f48_row3_col0, #T_a5f48_row3_col2, #T_a5f48_row4_col0, #T_a5f48_row4_col2, #T_a5f48_row6_col0, #T_a5f48_row6_col2, #T_a5f48_row7_col0, #T_a5f48_row7_col2 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row1_col1 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a5f48_row1_col2 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row2_col2 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row5_col0 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row5_col1, #T_a5f48_row5_col4 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a5f48_row5_col2 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_a5f48_row5_col3 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   background-color: rgb(183, 119, 41);
# }
# #T_a5f48_row5_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   background-color: rgb(183, 119, 41);
# }
# #T_a5f48_row8_col0 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a5f48_row8_col2 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a5f48_row9_col0, #T_a5f48_row9_col2, #T_a5f48_row10_col0, #T_a5f48_row10_col2 {
#   border: 5px solid red;
# }
# </style>
# <table id="T_a5f48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5f48_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_a5f48_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_a5f48_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_a5f48_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a5f48_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_a5f48_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_a5f48_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_a5f48_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_a5f48_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_a5f48_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_a5f48_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_a5f48_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_a5f48_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_a5f48_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_a5f48_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_a5f48_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_a5f48_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_a5f48_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_a5f48_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_a5f48_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_a5f48_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>

# %%
# Now find truely OPTIMAL MUSes
## Careful, this takes a while if you are not using Exact!
from cpmpy.tools.explain import optimal_mus

def get_weight(cons):
    if "william" in str(cons).lower():
        return 5
    else:
        return 1

solver = "exact" if "exact" in cp.SolverLookup.solvernames() else "ortools"
print("Using solver", solver)

conflict = optimal_mus(model.constraints, 
                       weights=[get_weight(c) for c in model.constraints],
                       solver=solver,
                       hs_solver="gurobi")
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Using solver exact
# Found conflict of size 4 in 14.7s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Megan has a day off on Thu 1
# - Kevin has a day off on Thu 1
# - Shift E on Thu 1 must be covered by 5 nurses out of 9
# - Shift L on Thu 1 must be covered by 3 nurses out of 9
# <style type="text/css">
# #T_df999 .data {
#   text-align: center;
# }
# #T_df999 .col_heading {
#   text-align: center;
# }
# #T_df999 .col7 {
#   border-left: 2px solid black;
# }
# #T_df999_row0_col0, #T_df999_row0_col1, #T_df999_row0_col2, #T_df999_row0_col4, #T_df999_row0_col5, #T_df999_row0_col6, #T_df999_row0_col7, #T_df999_row0_col8, #T_df999_row0_col9, #T_df999_row0_col10, #T_df999_row0_col11, #T_df999_row0_col12, #T_df999_row0_col13, #T_df999_row1_col0, #T_df999_row1_col1, #T_df999_row1_col2, #T_df999_row1_col4, #T_df999_row1_col5, #T_df999_row1_col6, #T_df999_row1_col7, #T_df999_row1_col8, #T_df999_row1_col9, #T_df999_row1_col10, #T_df999_row1_col11, #T_df999_row1_col12, #T_df999_row1_col13, #T_df999_row2_col0, #T_df999_row2_col1, #T_df999_row2_col2, #T_df999_row2_col4, #T_df999_row2_col5, #T_df999_row2_col6, #T_df999_row2_col7, #T_df999_row2_col8, #T_df999_row2_col9, #T_df999_row2_col10, #T_df999_row2_col11, #T_df999_row2_col12, #T_df999_row2_col13, #T_df999_row3_col0, #T_df999_row3_col1, #T_df999_row3_col2, #T_df999_row3_col4, #T_df999_row3_col5, #T_df999_row3_col6, #T_df999_row3_col7, #T_df999_row3_col8, #T_df999_row3_col9, #T_df999_row3_col10, #T_df999_row3_col11, #T_df999_row3_col12, #T_df999_row3_col13, #T_df999_row4_col0, #T_df999_row4_col1, #T_df999_row4_col2, #T_df999_row4_col4, #T_df999_row4_col5, #T_df999_row4_col6, #T_df999_row4_col7, #T_df999_row4_col8, #T_df999_row4_col9, #T_df999_row4_col10, #T_df999_row4_col11, #T_df999_row4_col12, #T_df999_row4_col13, #T_df999_row5_col0, #T_df999_row5_col1, #T_df999_row5_col2, #T_df999_row5_col4, #T_df999_row5_col5, #T_df999_row5_col6, #T_df999_row5_col7, #T_df999_row5_col8, #T_df999_row5_col9, #T_df999_row5_col10, #T_df999_row5_col11, #T_df999_row5_col12, #T_df999_row5_col13, #T_df999_row6_col0, #T_df999_row6_col1, #T_df999_row6_col2, #T_df999_row6_col4, #T_df999_row6_col5, #T_df999_row6_col6, #T_df999_row6_col7, #T_df999_row6_col8, #T_df999_row6_col9, #T_df999_row6_col10, #T_df999_row6_col11, #T_df999_row6_col12, #T_df999_row6_col13, #T_df999_row7_col0, #T_df999_row7_col1, #T_df999_row7_col2, #T_df999_row7_col4, #T_df999_row7_col5, #T_df999_row7_col6, #T_df999_row7_col7, #T_df999_row7_col8, #T_df999_row7_col9, #T_df999_row7_col10, #T_df999_row7_col11, #T_df999_row7_col12, #T_df999_row7_col13, #T_df999_row8_col0, #T_df999_row8_col1, #T_df999_row8_col2, #T_df999_row8_col4, #T_df999_row8_col5, #T_df999_row8_col6, #T_df999_row8_col7, #T_df999_row8_col8, #T_df999_row8_col9, #T_df999_row8_col10, #T_df999_row8_col11, #T_df999_row8_col12, #T_df999_row8_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_df999_row0_col3 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_df999_row1_col3, #T_df999_row2_col3, #T_df999_row3_col3, #T_df999_row4_col3, #T_df999_row5_col3, #T_df999_row6_col3 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_df999_row7_col3 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_df999_row8_col3 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_df999_row9_col3, #T_df999_row10_col3 {
#   border: 5px solid red;
# }
# </style>
# <table id="T_df999">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df999_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_df999_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_df999_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_df999_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_df999_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_df999_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_df999_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_df999_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_df999_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_df999_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_df999_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_df999_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_df999_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_df999_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_df999_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_df999_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_df999_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_df999_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_df999_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_df999_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_df999_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df999_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_df999_row0_col0" class="data row0 col0" ></td>
#       <td id="T_df999_row0_col1" class="data row0 col1" ></td>
#       <td id="T_df999_row0_col2" class="data row0 col2" ></td>
#       <td id="T_df999_row0_col3" class="data row0 col3" ></td>
#       <td id="T_df999_row0_col4" class="data row0 col4" ></td>
#       <td id="T_df999_row0_col5" class="data row0 col5" ></td>
#       <td id="T_df999_row0_col6" class="data row0 col6" ></td>
#       <td id="T_df999_row0_col7" class="data row0 col7" ></td>
#       <td id="T_df999_row0_col8" class="data row0 col8" ></td>
#       <td id="T_df999_row0_col9" class="data row0 col9" ></td>
#       <td id="T_df999_row0_col10" class="data row0 col10" ></td>
#       <td id="T_df999_row0_col11" class="data row0 col11" ></td>
#       <td id="T_df999_row0_col12" class="data row0 col12" ></td>
#       <td id="T_df999_row0_col13" class="data row0 col13" ></td>
#       <td id="T_df999_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_df999_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_df999_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_df999_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_df999_row1_col0" class="data row1 col0" ></td>
#       <td id="T_df999_row1_col1" class="data row1 col1" ></td>
#       <td id="T_df999_row1_col2" class="data row1 col2" ></td>
#       <td id="T_df999_row1_col3" class="data row1 col3" ></td>
#       <td id="T_df999_row1_col4" class="data row1 col4" ></td>
#       <td

# %% [markdown]
# ## Part 2, fixing UNSAT models
#
# Now that we know _why_ a model is UNSAT, we need to fix it.
#
# In the presentation, several techniques are shown for doing so.
#
# Below, you can find some skeleton code to play around with feasibiliy restoration techniques

# %%
model, nurse_view = factory.get_decision_model()
model.solve()
# Out:
# False

# %%
from cpmpy.tools.explain import mss_opt, mcs_opt

def get_weight(cons):
    if "cover" in str(cons):
        return 10
    return 1

# find Max-CSP solution
optimal_subset = mss_opt(model.constraints, hard=[],weights=[get_weight(c) for c in model.constraints])
mcs = set(model.constraints) - set(optimal_subset)
print("Found solution after dropping these constraints:")
for i,c in enumerate(mcs):
    print(f"{i}.", c)
# Out:
# Found solution after dropping these constraints:
# 0. Richard should have at least 2 consecutive days off
# 1. Robert can work at most 5 days before having a day off
# 2. Megan should have at least 2 consecutive days off
# 3. Jonathan should work at most 1 weekends
# 4. William should work at most 1 weekends
# 5. Jonathan should have at least 2 consecutive days off
# 6. Katherine has a day off on Tue 1
# 7. William should have at least 2 consecutive days off
# 8. William can work at most 5 days before having a day off
# 9. Kristen has a day off on Wed 2
# 10. Katherine should work at most 1 weekends
# 11. Katherine should have at least 2 consecutive days off
# 12. Robert should have at least 2 consecutive days off
# 13. Megan has a day off on Thu 1
# 14. Richard can work at most 5 days before having a day off
# 15. Shift 1 cannot follow [1] for Katherine
# 16. Thomas should work at most 1 weekends

# %%
assert cp.Model(optimal_subset).solve() is True
visualize(nurse_view.value(), factory)
visualize_constraints(mcs, nurse_view, factory, do_clear=False)
# Out:
# <style type="text/css">
# #T_a989d .data {
#   text-align: center;
# }
# #T_a989d .col_heading {
#   text-align: center;
# }
# #T_a989d .col7 {
#   border-left: 2px solid black;
# }
# #T_a989d_row0_col0, #T_a989d_row0_col1, #T_a989d_row0_col2, #T_a989d_row0_col12, #T_a989d_row0_col13, #T_a989d_row1_col3, #T_a989d_row1_col7, #T_a989d_row1_col8, #T_a989d_row1_col9, #T_a989d_row1_col10, #T_a989d_row2_col3, #T_a989d_row2_col4, #T_a989d_row2_col5, #T_a989d_row2_col6, #T_a989d_row3_col0, #T_a989d_row3_col1, #T_a989d_row3_col2, #T_a989d_row3_col3, #T_a989d_row3_col4, #T_a989d_row3_col9, #T_a989d_row3_col10, #T_a989d_row5_col9, #T_a989d_row6_col0, #T_a989d_row7_col0, #T_a989d_row7_col1, #T_a989d_row7_col5, #T_a989d_row7_col6, #T_a989d_row7_col7, #T_a989d_row7_col12, #T_a989d_row8_col1, #T_a989d_row8_col2, #T_a989d_row8_col3, #T_a989d_row8_col4, #T_a989d_row8_col7, #T_a989d_row8_col10, #T_a989d_row8_col11 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_a989d_row0_col3 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   background-color: lightgreen;
# }
# #T_a989d_row0_col4, #T_a989d_row1_col4, #T_a989d_row2_col7, #T_a989d_row3_col7, #T_a989d_row4_col1, #T_a989d_row5_col7 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   border-left: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a989d_row0_col5 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a989d_row0_col6, #T_a989d_row0_col7, #T_a989d_row0_col8, #T_a989d_row0_col9, #T_a989d_row1_col0, #T_a989d_row1_col2, #T_a989d_row2_col0, #T_a989d_row4_col0, #T_a989d_row4_col10, #T_a989d_row4_col11, #T_a989d_row5_col10, #T_a989d_row5_col11, #T_a989d_row5_col12, #T_a989d_row6_col1, #T_a989d_row6_col2, #T_a989d_row6_col3, #T_a989d_row6_col4, #T_a989d_row6_col8, #T_a989d_row6_col10, #T_a989d_row6_col11, #T_a989d_row6_col12, #T_a989d_row6_col13, #T_a989d_row7_col2, #T_a989d_row7_col8, #T_a989d_row7_col9, #T_a989d_row7_col13 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
# }
# #T_a989d_row0_col10, #T_a989d_row0_col11, #T_a989d_row1_col11, #T_a989d_row2_col1, #T_a989d_row2_col2, #T_a989d_row3_col11, #T_a989d_row4_col8, #T_a989d_row4_col9, #T_a989d_row5_col0, #T_a989d_row5_col13, #T_a989d_row6_col5, #T_a989d_row6_col6, #T_a989d_row6_col7, #T_a989d_row7_col3, #T_a989d_row7_col4, #T_a989d_row7_col10, #T_a989d_row7_col11, #T_a989d_row8_col0, #T_a989d_row8_col8, #T_a989d_row8_col9 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# #T_a989d_row1_col1, #T_a989d_row6_col9 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   background-color: lightgreen;
# }
# #T_a989d_row1_col5 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a989d_row1_col6, #T_a989d_row3_col6, #T_a989d_row3_col13, #T_a989d_row8_col6, #T_a989d_row8_col13 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_a989d_row1_col12, #T_a989d_row3_col12 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_a989d_row1_col13, #T_a989d_row4_col13 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_a989d_row2_col8 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a989d_row2_col9, #T_a989d_row2_col10, #T_a989d_row2_col11, #T_a989d_row2_col12 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row2_col13, #T_a989d_row4_col7, #T_a989d_row5_col6 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row3_col5, #T_a989d_row8_col5, #T_a989d_row8_col12 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_a989d_row3_col8, #T_a989d_row5_col8 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_a989d_row4_col2 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row4_col3, #T_a989d_row4_col4, #T_a989d_row5_col2, #T_a989d_row5_col3, #T_a989d_row5_col4, #T_a989d_row5_col5 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row4_col5 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row4_col6 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_a989d_row4_col12 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_a989d_row5_col1 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# </style>
# <table id="T_a989d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a989d_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_a989d_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_a989d_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_a989d_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a989d_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_a989d_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_a989d_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_a989d_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_a989d_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_a989d_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_a989d_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_a989d_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_a989d_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_a989d_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_a989d_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_a989d_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_a989d_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_a989d_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th i

# %% [markdown]
# ### Slack-based relaxation
#
# Apart from dropping constraints, they can also be _relaxed_ when numeric

# %%
model, nurse_view, slack_under, slack_over = factory.get_slack_model()  # CMPpy Model

# TODO..

# %%
import math

480 * 11
# Out:
# 5280
