# %%
# # code required to run on a fresh install or in google colab
# ! git clone https://github.com/CPMpy/XCP-explain.git /tmp/XCP-explain
# ! cd XCP-explain && git checkout ecai24
# ! pip install -r XCP-explain/requirements.txt
# ! pip install cpmpy

# # add XCP-explain to the Python path
# import sys
# root = "/tmp/XCP-explain"
# if root not in sys.path:
#     sys.path.insert(0, root)
root= "."

# %%
# %load_ext autoreload
# %autoreload 2
"""
    Some imports used throughout the notebook
"""
import time
import os
from visualize import *

from cpmpy.transformations.normalize import toplevel_list
from factory import *
from read_data import get_data
from IPython.display import clear_output


import numpy as np
np.set_printoptions(linewidth=90)
# preload solvers
from cpmpy import SolverLookup
names = SolverLookup.solvernames()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-06-03

# %% [markdown]
# ## Hands-on causal explanations
#
# In this notebook, you will get experience with computing causal explanations.
#
# We focus on explaining unsatisfiability by means of extracting a MUS.
#
#
#
# <img src="img/mus.png" width="20%" align="right" style="margin:50px;">
#
# Trim model to minimal set of constraints
#
# ... minimize cognitive burden for user

# %%
instance = os.path.join(root,"Benchmarks/Instance1.txt")
data = get_data(instance)
factory = NurseSchedulingFactory(data)

# %% [markdown]
# Let's have a look at the instance and its (optimal) solution.

# %%
data.staff[["name", "MaxShifts","MaxWeekends"]]
# Out:
#         name MaxShifts  MaxWeekends
# 0      Megan      D=14            1
# 1  Katherine      D=14            1
# 2     Robert      D=14            1
# 3   Jonathan      D=14            1
# 4    William      D=14            1
# 5    Richard      D=14            1
# 6    Kristen      D=14            1
# 7      Kevin      D=14            1

# %%
print(f"Planning for {data.horizon} days")
# Out:
# Planning for 14 days

# %%
model, nurse_view = factory.get_optimization_model()
assert model.solve(solver="ortools") # you can try different solvers here!


print(model.status())
print("Total penalty:", model.objective_value())
visualize(nurse_view.value(), factory)
# Out:
# ExitStatus.OPTIMAL (0.087745 seconds)
# Total penalty: 607
# <style type="text/css">
# #T_08eff .data {
#   text-align: center;
# }
# #T_08eff .col_heading {
#   text-align: center;
# }
# #T_08eff .col7 {
#   border-left: 2px solid black;
# }
# #T_08eff_row0_col0, #T_08eff_row0_col5, #T_08eff_row0_col6, #T_08eff_row0_col10, #T_08eff_row0_col11, #T_08eff_row1_col5, #T_08eff_row1_col6, #T_08eff_row1_col9, #T_08eff_row1_col10, #T_08eff_row1_col11, #T_08eff_row2_col3, #T_08eff_row2_col4, #T_08eff_row2_col7, #T_08eff_row2_col8, #T_08eff_row2_col12, #T_08eff_row2_col13, #T_08eff_row3_col2, #T_08eff_row3_col3, #T_08eff_row3_col4, #T_08eff_row3_col10, #T_08eff_row3_col11, #T_08eff_row3_col12, #T_08eff_row3_col13, #T_08eff_row4_col0, #T_08eff_row4_col5, #T_08eff_row4_col6, #T_08eff_row4_col9, #T_08eff_row4_col10, #T_08eff_row4_col13, #T_08eff_row5_col3, #T_08eff_row5_col4, #T_08eff_row5_col5, #T_08eff_row5_col6, #T_08eff_row5_col9, #T_08eff_row5_col10, #T_08eff_row6_col0, #T_08eff_row6_col1, #T_08eff_row6_col5, #T_08eff_row6_col6, #T_08eff_row6_col9, #T_08eff_row6_col10, #T_08eff_row7_col2, #T_08eff_row7_col3, #T_08eff_row7_col6, #T_08eff_row7_col7, #T_08eff_row7_col12, #T_08eff_row7_col13 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# #T_08eff_row0_col1, #T_08eff_row0_col2, #T_08eff_row0_col3, #T_08eff_row0_col4, #T_08eff_row0_col7, #T_08eff_row0_col8, #T_08eff_row0_col9, #T_08eff_row0_col12, #T_08eff_row0_col13, #T_08eff_row1_col0, #T_08eff_row1_col1, #T_08eff_row1_col2, #T_08eff_row1_col3, #T_08eff_row1_col4, #T_08eff_row1_col7, #T_08eff_row1_col8, #T_08eff_row1_col12, #T_08eff_row1_col13, #T_08eff_row2_col0, #T_08eff_row2_col1, #T_08eff_row2_col2, #T_08eff_row2_col5, #T_08eff_row2_col6, #T_08eff_row2_col9, #T_08eff_row2_col10, #T_08eff_row2_col11, #T_08eff_row3_col0, #T_08eff_row3_col1, #T_08eff_row3_col5, #T_08eff_row3_col6, #T_08eff_row3_col7, #T_08eff_row3_col8, #T_08eff_row3_col9, #T_08eff_row4_col1, #T_08eff_row4_col2, #T_08eff_row4_col3, #T_08eff_row4_col4, #T_08eff_row4_col7, #T_08eff_row4_col8, #T_08eff_row4_col11, #T_08eff_row4_col12, #T_08eff_row5_col0, #T_08eff_row5_col1, #T_08eff_row5_col2, #T_08eff_row5_col7, #T_08eff_row5_col8, #T_08eff_row5_col11, #T_08eff_row5_col12, #T_08eff_row5_col13, #T_08eff_row6_col2, #T_08eff_row6_col3, #T_08eff_row6_col4, #T_08eff_row6_col7, #T_08eff_row6_col8, #T_08eff_row6_col11, #T_08eff_row6_col12, #T_08eff_row6_col13, #T_08eff_row7_col0, #T_08eff_row7_col1, #T_08eff_row7_col4, #T_08eff_row7_col5, #T_08eff_row7_col8, #T_08eff_row7_col9, #T_08eff_row7_col10, #T_08eff_row7_col11 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# </style>
# <table id="T_08eff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08eff_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_08eff_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_08eff_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_08eff_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_08eff_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_08eff_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_08eff_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_08eff_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_08eff_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_08eff_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_08eff_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_08eff_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_08eff_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_08eff_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_08eff_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_08eff_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_08eff_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_08eff_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_08eff_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_08eff_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08eff_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_08eff_row0_col0" class="data row0 col0" >F</td>
#       <td id="T_08eff_row0_col1" class="data row0 col1" >D</td>
#       <td id="T_08eff_row0_col2" class="data row0 col2" >D</td>
#       <td id="T_08eff_row0_col3" class="data row0 col3" >D</td>
#       <td id="T_08eff_row0_col4" class="data row0 col4" >D</td>
#       <td id="T_08eff_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_08eff_row0_col6" class="data row0 col6" >F</td>
#       <td id="T_08eff_row0_col7" class="data row0 col7" >D</td>
#       <td id="T_08eff_row0_col8" class="data row0 col8" >D</td>
#       <td id="T_08eff_row0_col9" class="data row0 col9" >D</td>
#       <td id="T_08eff_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_08eff_row0_col11" class="data row0 col11" >F</td>
#       <td id="T_08eff_row0_col12" class="data row0 col12" >D</td>
#       <td id="T_08eff_row0_col13" class="data row0 col13" >D</td>
#       <td id="T_08eff_row0_col14" class="data row0 col14" >9</td>
#       <td id="T_08eff_row0_col15" class="data row0 col15" >4320</td>
#     </tr>
#     <tr>
#       <th id="T_08eff_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_08eff_row1_col0" class="data row1 col0" >D</td>
#       <td id="T_08eff_row1_col1" class="data row1 col1" >D</td>
#       <td id="T_08eff_row1_col2" class="data row1 col2" >D</td>
#       <td id="T_08eff_row1_col3" class="data row1 col3" >D</td>
#       <td id="T_08eff_row1_col4" class="data row1 col4" >D</td>
#       <td id="T_08eff_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_08eff_row1_col6" class="data row1 col6" >F</td>
#       <td id="T_08eff_row1_col7" class="data row1 col7" >D</td>
#       <td id="T_08eff_row1_col8" class="data row1 col8" >D</td>
#       <td id="T_08eff_row1_col9" class="data row1 col9" >F</td>
#       <td id="T_08eff_row1_col10" class="data row1 col10" >F</td>
#       <td id="T_08eff_row1_col11" class="data row1 col11" >F</td>
#       <td id="T_08eff_row1_col12" class="data row1 col12" >D</td>
#       <td id="T_08eff_row1_col13" class="data row1 col13" >D</td>
#       <td id="T_08eff_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_08eff_row1_col15" class="data row1 col15" >4320</td>
#     </tr>
#     <tr>
#       <th id="T_08eff_level0_row2" class="row_heading level0 row2" >Robert</th>
#       <td id="T_08eff_row2_col0" class="data row2 col0" >D</td>
#       <td id="T_08eff_row2_col1" class="data row2 col1" >D</td>
#       <td id="T_08eff_row2_col2" class="data row2 col2" >D</td>
#       <td id="T_08eff_row2_col3" class="data row2 col3" >F</td>
#       <td id="T_08eff_row2_col4" class="data row2 col4" >F</td>
#       <td id="T_08eff_row2_col5" class="data row2 col5" >D</td>
#       <td id="T_08eff_row2_col6" class="data row2 col6" >D</td>
#       <td id="T_08eff_row2_col7" class="data row2 col7" >F</td>
#       <td id="T_08eff_row2_col

# %%
requests, _ = factory.shift_on_requests(formulation="hard")

denied_requests = [req for req in requests if req.value() is False]
print("The following requests were denied:")
for req in denied_requests:
    print("-", req)

visualize_constraints(denied_requests, nurse_view, factory, do_clear=False)
# Out:
# The following requests were denied:
# - Robert requests to work shift D on Thu 1
# - Robert requests to work shift D on Fri 1
# - Kevin requests to work shift D on Sat 2
# - Kevin requests to work shift D on Sun 2
# <style type="text/css">
# #T_842bf .data {
#   text-align: center;
# }
# #T_842bf .col_heading {
#   text-align: center;
# }
# #T_842bf .col7 {
#   border-left: 2px solid black;
# }
# #T_842bf_row0_col0, #T_842bf_row0_col5, #T_842bf_row0_col6, #T_842bf_row0_col10, #T_842bf_row0_col11, #T_842bf_row1_col5, #T_842bf_row1_col6, #T_842bf_row1_col9, #T_842bf_row1_col10, #T_842bf_row1_col11, #T_842bf_row2_col7, #T_842bf_row2_col8, #T_842bf_row2_col12, #T_842bf_row2_col13, #T_842bf_row3_col2, #T_842bf_row3_col3, #T_842bf_row3_col4, #T_842bf_row3_col10, #T_842bf_row3_col11, #T_842bf_row3_col12, #T_842bf_row3_col13, #T_842bf_row4_col0, #T_842bf_row4_col5, #T_842bf_row4_col6, #T_842bf_row4_col9, #T_842bf_row4_col10, #T_842bf_row4_col13, #T_842bf_row5_col3, #T_842bf_row5_col4, #T_842bf_row5_col5, #T_842bf_row5_col6, #T_842bf_row5_col9, #T_842bf_row5_col10, #T_842bf_row6_col0, #T_842bf_row6_col1, #T_842bf_row6_col5, #T_842bf_row6_col6, #T_842bf_row6_col9, #T_842bf_row6_col10, #T_842bf_row7_col2, #T_842bf_row7_col3, #T_842bf_row7_col6, #T_842bf_row7_col7 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# #T_842bf_row0_col1, #T_842bf_row0_col2, #T_842bf_row0_col3, #T_842bf_row0_col4, #T_842bf_row0_col7, #T_842bf_row0_col8, #T_842bf_row0_col9, #T_842bf_row0_col12, #T_842bf_row0_col13, #T_842bf_row1_col0, #T_842bf_row1_col1, #T_842bf_row1_col2, #T_842bf_row1_col3, #T_842bf_row1_col4, #T_842bf_row1_col7, #T_842bf_row1_col8, #T_842bf_row1_col12, #T_842bf_row1_col13, #T_842bf_row2_col0, #T_842bf_row2_col1, #T_842bf_row2_col2, #T_842bf_row2_col5, #T_842bf_row2_col6, #T_842bf_row2_col9, #T_842bf_row2_col10, #T_842bf_row2_col11, #T_842bf_row3_col0, #T_842bf_row3_col1, #T_842bf_row3_col5, #T_842bf_row3_col6, #T_842bf_row3_col7, #T_842bf_row3_col8, #T_842bf_row3_col9, #T_842bf_row4_col1, #T_842bf_row4_col2, #T_842bf_row4_col3, #T_842bf_row4_col4, #T_842bf_row4_col7, #T_842bf_row4_col8, #T_842bf_row4_col11, #T_842bf_row4_col12, #T_842bf_row5_col0, #T_842bf_row5_col1, #T_842bf_row5_col2, #T_842bf_row5_col7, #T_842bf_row5_col8, #T_842bf_row5_col11, #T_842bf_row5_col12, #T_842bf_row5_col13, #T_842bf_row6_col2, #T_842bf_row6_col3, #T_842bf_row6_col4, #T_842bf_row6_col7, #T_842bf_row6_col8, #T_842bf_row6_col11, #T_842bf_row6_col12, #T_842bf_row6_col13, #T_842bf_row7_col0, #T_842bf_row7_col1, #T_842bf_row7_col4, #T_842bf_row7_col5, #T_842bf_row7_col8, #T_842bf_row7_col9, #T_842bf_row7_col10, #T_842bf_row7_col11 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_842bf_row2_col3, #T_842bf_row2_col4, #T_842bf_row7_col12, #T_842bf_row7_col13 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   background-color: rgb(183, 119, 41);
# }
# </style>
# <table id="T_842bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_842bf_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_842bf_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_842bf_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_842bf_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_842bf_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_842bf_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_842bf_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_842bf_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_842bf_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_842bf_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_842bf_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_842bf_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_842bf_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_842bf_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_842bf_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_842bf_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_842bf_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_842bf_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_842bf_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_842bf_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_842bf_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_842bf_row0_col0" class="data row0 col0" >F</td>
#       <td id="T_842bf_row0_col1" class="data row0 col1" >D</td>
#       <td id="T_842bf_row0_col2" class="data row0 col2" >D</td>
#       <td id="T_842bf_row0_col3" class="data row0 col3" >D</td>
#       <td id="T_842bf_row0_col4" class="data row0 col4" >D</td>
#       <td id="T_842bf_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_842bf_row0_col6" class="data row0 col6" >F</td>
#       <td id="T_842bf_row0_col7" class="data row0 col7" >D</td>
#       <td id="T_842bf_row0_col8" class="data row0 col8" >D</td>
#       <td id="T_842bf_row0_col9" class="data row0 col9" >D</td>
#       <td id="T_842bf_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_842bf_row0_col11" class="data row0 col11" >F</td>
#       <td id="T_842bf_row0_col12" class="data row0 col12" >D</td>
#       <td id="T_842bf_row0_col13" class="data row0 col13" >D</td>
#       <td id="T_842bf_row0_col14" class="data row0 col14" >9</td>
#       <td id="T_842bf_row0_col15" class="data row0 col15" >4320</td>
#     </tr>
#     <tr>
#       <th id="T_842bf_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_842bf_row1_col0" class="data row1 col0" >D</td>
#       <td id="T_842bf_row1_col1" class="data row1 col1" >D</td>
#       <td id="T_842bf_row1_col2" class="data row1 col2" >D</td>
#       <td id="T_842bf_row1_col3" class="data row1 col3" >D</td>
#       <td id="T_842bf_row1_col4" class="data row1 col4" >D</td>
#       <td id="T_842bf_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_842bf_row1_col6" class="data row1 col6" >F</td>
#       <td id="T_842bf_row1_col7" class="data row1 col7" >D</td>
#       <td id="T_842bf_row1_col8" class="data row1 col8" >D</td>
#       <td id="T_842bf_row1_col9" class="data row1 col9" >F</td>
#       <td id="T_842bf_row1_col10" class="data row1 col10" >F</td>
#       <td id="T_842bf_row1_col11" class="data row1 col11" >F</td>
#       <td id="T_842bf_row1_col12" class="data row1 col12" >D</td>
#       <td id="T_842bf_row1_col13" class="data row1 col13" >D</td>
#       <td id="T_842bf_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_842bf_row1_col15" class="data row1 col15" >4320</td>
#     </tr>
#     <tr>
#       <th id="T_842bf_level0_row2" class="row_heading level0 row2" >Robert</th>
#       <td id="T_842bf_row2_col0" class="data row2 col0" >D</td>
#       <td id="T_842bf_row2_col1" class="data row2 col1" >D</td>
#       <td id="T_842bf_row2_col2" class="data row2 col2" >D</td>
#       <td id="T_842bf_row2_col3" class="data row2 col3" >F</td>
#       <td id="T_842bf_row2_col4" class="data row2 col4" >F</td>
#       <td id="T_842bf_row2_col5" class="data row2 col5" >D</td>
#       <td id="T_842bf_row2_col6" class="data row2 c

# %%
# try it yourself!

# requests, _ = factory.shift_off_requests(formulation="hard")
# cover_constraints, _ = factory.cover(formulation="hard")

# TODO: find out which are not satisfied, and visualize!

# %% [markdown]
# ## Deductive explanations
#
# In the remainder of this notebook, we will explore different ways of explaining unsatisfiabily of the instance.

# %%
model, nurse_view = factory.get_decision_model()
model.solve()
# Out:
# False

# %%
from cpmpy.tools.explain import mus

t0 = time.time()
conflict = mus(model.constraints) # try different solvers here!
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 11 in 0.69s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Robert requests to work shift D on Wed 1
# - Shift D on Sat 1 must be covered by 5 nurses out of 8
# - Robert can work at most 5 days before having a day off
# - Kevin should work at most 1 weekends
# - Robert requests to work shift D on Tue 1
# - Robert requests to work shift D on Thu 1
# - Kevin requests to work shift D on Sat 2
# - Robert requests to work shift D on Fri 1
# - Katherine has a day off on Sat 1
# - Robert requests to work shift D on Mon 1
# - Richard has a day off on Sat 1
# <style type="text/css">
# #T_764e8 .data {
#   text-align: center;
# }
# #T_764e8 .col_heading {
#   text-align: center;
# }
# #T_764e8 .col7 {
#   border-left: 2px solid black;
# }
# #T_764e8_row0_col0, #T_764e8_row0_col1, #T_764e8_row0_col2, #T_764e8_row0_col3, #T_764e8_row0_col4, #T_764e8_row0_col6, #T_764e8_row0_col7, #T_764e8_row0_col8, #T_764e8_row0_col9, #T_764e8_row0_col10, #T_764e8_row0_col11, #T_764e8_row0_col12, #T_764e8_row0_col13, #T_764e8_row1_col0, #T_764e8_row1_col1, #T_764e8_row1_col2, #T_764e8_row1_col3, #T_764e8_row1_col4, #T_764e8_row1_col6, #T_764e8_row1_col7, #T_764e8_row1_col8, #T_764e8_row1_col9, #T_764e8_row1_col10, #T_764e8_row1_col11, #T_764e8_row1_col12, #T_764e8_row1_col13, #T_764e8_row2_col6, #T_764e8_row2_col7, #T_764e8_row2_col8, #T_764e8_row2_col9, #T_764e8_row2_col10, #T_764e8_row2_col11, #T_764e8_row2_col12, #T_764e8_row2_col13, #T_764e8_row3_col0, #T_764e8_row3_col1, #T_764e8_row3_col2, #T_764e8_row3_col3, #T_764e8_row3_col4, #T_764e8_row3_col6, #T_764e8_row3_col7, #T_764e8_row3_col8, #T_764e8_row3_col9, #T_764e8_row3_col10, #T_764e8_row3_col11, #T_764e8_row3_col12, #T_764e8_row3_col13, #T_764e8_row4_col0, #T_764e8_row4_col1, #T_764e8_row4_col2, #T_764e8_row4_col3, #T_764e8_row4_col4, #T_764e8_row4_col6, #T_764e8_row4_col7, #T_764e8_row4_col8, #T_764e8_row4_col9, #T_764e8_row4_col10, #T_764e8_row4_col11, #T_764e8_row4_col12, #T_764e8_row4_col13, #T_764e8_row5_col0, #T_764e8_row5_col1, #T_764e8_row5_col2, #T_764e8_row5_col3, #T_764e8_row5_col4, #T_764e8_row5_col6, #T_764e8_row5_col7, #T_764e8_row5_col8, #T_764e8_row5_col9, #T_764e8_row5_col10, #T_764e8_row5_col11, #T_764e8_row5_col12, #T_764e8_row5_col13, #T_764e8_row6_col0, #T_764e8_row6_col1, #T_764e8_row6_col2, #T_764e8_row6_col3, #T_764e8_row6_col4, #T_764e8_row6_col6, #T_764e8_row6_col7, #T_764e8_row6_col8, #T_764e8_row6_col9, #T_764e8_row6_col10, #T_764e8_row6_col11, #T_764e8_row6_col12, #T_764e8_row6_col13, #T_764e8_row7_col0, #T_764e8_row7_col1, #T_764e8_row7_col2, #T_764e8_row7_col3, #T_764e8_row7_col4, #T_764e8_row7_col7, #T_764e8_row7_col8, #T_764e8_row7_col9, #T_764e8_row7_col10, #T_764e8_row7_col11 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_764e8_row0_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_764e8_row1_col5, #T_764e8_row5_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   background-color: lightgreen;
# }
# #T_764e8_row2_col0 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   background-color: rgb(183, 119, 41);
# }
# #T_764e8_row2_col1, #T_764e8_row2_col3, #T_764e8_row2_col4 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   background-color: rgb(183, 119, 41);
# }
# #T_764e8_row2_col2 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: rgb(183, 119, 41);
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_764e8_row2_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_764e8_row3_col5, #T_764e8_row4_col5, #T_764e8_row6_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_764e8_row7_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_764e8_row7_col6, #T_764e8_row7_col13 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_764e8_row7_col12 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   background-color: rgb(183, 119, 41);
# }
# #T_764e8_row8_col5 {
#   border: 5px solid red;
# }
# </style>
# <table id="T_764e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_764e8_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_764e8_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_764e8_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_764e8_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_764e8_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_764e8_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_764e8_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_764e8_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_764e8_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_764e8_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_764e8_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_764e8_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_764e8_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_764e8_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_764e8_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_764e8_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_764e8_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_764e8_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_764e8_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_764e8_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_764e8_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_764e8_row0_col0" class="data row0 col0" ></td>
#       <td id="T_764e8_row0_col1" class="data row0 col1" ></td>
#       <td id="T_764e8_row0_col2" class="data row0 col2" ></td>
#       <td id="T_764e8_row0_col3" class="data row0 col3" ></td>
#       <td id="T_764e8_row0_col4" class="data row0 col4" ></td>
#       <td id="T_764e8_row0_col5" class="data row0 col5" ></td>
#       <td id="T_764e8_row0_col6" class="data row0 col6" ></td>
#       <td id="T_764e8_row0_col7" class="data row0 col7" ></td>
#       <td id="T_764e8_row0_col8" class="data row0 col8" ></td>
#       <td id="T_764e8_row0_col9" class="data row0 col9" ></td>
#       <td id="T_764e8_row0_col10" class="data row0 col10" ></td>
#       <td id="T_764e8_row0_col11" class="data row0 col11" ></td>
#       <td id="T_764e8_row0_col12" class="data row0 col12" ></td>
#       <td id="T_764e8_row0_col13" class="data row0 col13" ></td>
#       <td id="T_764e8_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_764e8_row0_col15" class="data row0 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_764e8_level0_row1" class="row_heading level0 row1" >Katherine</th

# %% [markdown]
# Now, let's influence the MUS we would like to find.
#
# We can chose from QuickXplain [1] or Optimal MUS (OUS) [2]
#
# **QuickXplain** takes as input a total ordering of constraints, and returns a lexicographically minimal MUS.
# The algorithm is build up as a divide-and-conquer approach, and therefore has a good average complexity.
#
# **OUS** takes as input a weight for each constraint, and finds a **optimal** MUS. While this optimality guarantee is sometimes required, it comes at a penalty of longer computation times, as you will notice here!

# %%
# QuickXplain first
from cpmpy.tools.explain import quickxplain


def get_weight(cons):
    if "William" in str(cons): # Find a different MUS than the previous
        return 2 
    return 1

ordered = sorted(model.constraints, key=get_weight)
conflict = quickxplain(ordered)
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 11 in 3.1s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Robert can work at most 5 days before having a day off
# - Kevin should work at most 1 weekends
# - Katherine has a day off on Sat 1
# - Richard has a day off on Sat 1
# - Robert should have at least 2 consecutive days off
# - Robert should have at least 2 consecutive days off
# - Robert requests to work shift D on Mon 1
# - Robert requests to work shift D on Tue 1
# - Robert requests to work shift D on Thu 1
# - Kevin requests to work shift D on Sat 2
# - Shift D on Sat 1 must be covered by 5 nurses out of 8
# <style type="text/css">
# #T_89dc4 .data {
#   text-align: center;
# }
# #T_89dc4 .col_heading {
#   text-align: center;
# }
# #T_89dc4 .col7 {
#   border-left: 2px solid black;
# }
# #T_89dc4_row0_col0, #T_89dc4_row0_col1, #T_89dc4_row0_col2, #T_89dc4_row0_col3, #T_89dc4_row0_col4, #T_89dc4_row0_col6, #T_89dc4_row0_col7, #T_89dc4_row0_col8, #T_89dc4_row0_col9, #T_89dc4_row0_col10, #T_89dc4_row0_col11, #T_89dc4_row0_col12, #T_89dc4_row0_col13, #T_89dc4_row1_col0, #T_89dc4_row1_col1, #T_89dc4_row1_col2, #T_89dc4_row1_col3, #T_89dc4_row1_col4, #T_89dc4_row1_col6, #T_89dc4_row1_col7, #T_89dc4_row1_col8, #T_89dc4_row1_col9, #T_89dc4_row1_col10, #T_89dc4_row1_col11, #T_89dc4_row1_col12, #T_89dc4_row1_col13, #T_89dc4_row2_col6, #T_89dc4_row2_col7, #T_89dc4_row2_col8, #T_89dc4_row2_col9, #T_89dc4_row2_col10, #T_89dc4_row2_col11, #T_89dc4_row2_col12, #T_89dc4_row2_col13, #T_89dc4_row3_col0, #T_89dc4_row3_col1, #T_89dc4_row3_col2, #T_89dc4_row3_col3, #T_89dc4_row3_col4, #T_89dc4_row3_col6, #T_89dc4_row3_col7, #T_89dc4_row3_col8, #T_89dc4_row3_col9, #T_89dc4_row3_col10, #T_89dc4_row3_col11, #T_89dc4_row3_col12, #T_89dc4_row3_col13, #T_89dc4_row4_col0, #T_89dc4_row4_col1, #T_89dc4_row4_col2, #T_89dc4_row4_col3, #T_89dc4_row4_col4, #T_89dc4_row4_col6, #T_89dc4_row4_col7, #T_89dc4_row4_col8, #T_89dc4_row4_col9, #T_89dc4_row4_col10, #T_89dc4_row4_col11, #T_89dc4_row4_col12, #T_89dc4_row4_col13, #T_89dc4_row5_col0, #T_89dc4_row5_col1, #T_89dc4_row5_col2, #T_89dc4_row5_col3, #T_89dc4_row5_col4, #T_89dc4_row5_col6, #T_89dc4_row5_col7, #T_89dc4_row5_col8, #T_89dc4_row5_col9, #T_89dc4_row5_col10, #T_89dc4_row5_col11, #T_89dc4_row5_col12, #T_89dc4_row5_col13, #T_89dc4_row6_col0, #T_89dc4_row6_col1, #T_89dc4_row6_col2, #T_89dc4_row6_col3, #T_89dc4_row6_col4, #T_89dc4_row6_col6, #T_89dc4_row6_col7, #T_89dc4_row6_col8, #T_89dc4_row6_col9, #T_89dc4_row6_col10, #T_89dc4_row6_col11, #T_89dc4_row6_col12, #T_89dc4_row6_col13, #T_89dc4_row7_col0, #T_89dc4_row7_col1, #T_89dc4_row7_col2, #T_89dc4_row7_col3, #T_89dc4_row7_col4, #T_89dc4_row7_col7, #T_89dc4_row7_col8, #T_89dc4_row7_col9, #T_89dc4_row7_col10, #T_89dc4_row7_col11 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_89dc4_row0_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_89dc4_row1_col5, #T_89dc4_row5_col5 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_89dc4_row2_col0 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   background-color: rgb(183, 119, 41);
# }
# #T_89dc4_row2_col1 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   background-color: rgb(183, 119, 41);
# }
# #T_89dc4_row2_col2, #T_89dc4_row2_col4 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-left: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_89dc4_row2_col3 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   background-color: rgb(183, 119, 41);
# }
# #T_89dc4_row2_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px solid red;
#   border-top: 5px solid red;
#   border-bottom: 5px solid red;
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_89dc4_row3_col5, #T_89dc4_row4_col5, #T_89dc4_row6_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_89dc4_row7_col5 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_89dc4_row7_col6, #T_89dc4_row7_col13 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_89dc4_row7_col12 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
#   background-color: rgb(183, 119, 41);
# }
# #T_89dc4_row8_col5 {
#   border: 5px solid red;
# }
# </style>
# <table id="T_89dc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89dc4_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_89dc4_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_89dc4_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_89dc4_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_89dc4_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_89dc4_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_89dc4_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_89dc4_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_89dc4_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_89dc4_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_89dc4_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_89dc4_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_89dc4_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_89dc4_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_89dc4_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_89dc4_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_89dc4_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_89dc4_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_89dc4_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_89dc4_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89dc4_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_89dc4_row0_col0" class="data row0 col0" ></td>
#       <td id="T_89dc4_row0_col1" class="data row0 col1" ></td>
#       <td id="T_89dc4_row0_col2" class="data row0 col2" ></td>
#       <td id="T_89dc4_row0_col3" class="data row0 col3" ></td>
#       <td id="T_89dc4_row0_col4" class="data row0 col4" ></td>
#       <td id="T_89dc4_row0_col5" class="data row0 col5" ></td>
#       <td id="T_89dc4_row0_col6" class="data row0 col6" ></td>
#       <td id="T_89dc4_row0_col7" class="data row0 col7" ></td>
#       <td id="T_89dc4_row0_col8" class="data row0 col8" ></td>
#       <td id="T_89dc4_row0_col9" class="data row0 col9" ></td>
#       <td id="T_89dc4_row0_

# %%
# Now find truely OPTIMAL MUSes
## Careful, this takes a while if you are not using Exact!
from cpmpy.tools.explain import optimal_mus

def get_weight(cons):
    if "william" in str(cons).lower():
        return 5
    else:
        return 1
#     return len(str(cons)) # favor constraints with short description


solver = "exact" if "exact" in cp.SolverLookup.solvernames() else "ortools"
print("Using solver", solver)

conflict = optimal_mus(model.constraints, 
                       weights=[get_weight(c) for c in model.constraints],
                       solver=solver,
                       hs_solver="gurobi")
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Using solver exact
# Found conflict of size 3 in 4.76s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Robert has a day off on Tue 2
# - Richard requests not to work shift D on Tue 2
# - Shift D on Tue 2 must be covered by 7 nurses out of 8
# <style type="text/css">
# #T_0c66e .data {
#   text-align: center;
# }
# #T_0c66e .col_heading {
#   text-align: center;
# }
# #T_0c66e .col7 {
#   border-left: 2px solid black;
# }
# #T_0c66e_row0_col0, #T_0c66e_row0_col1, #T_0c66e_row0_col2, #T_0c66e_row0_col3, #T_0c66e_row0_col4, #T_0c66e_row0_col5, #T_0c66e_row0_col6, #T_0c66e_row0_col7, #T_0c66e_row0_col9, #T_0c66e_row0_col10, #T_0c66e_row0_col11, #T_0c66e_row0_col12, #T_0c66e_row0_col13, #T_0c66e_row1_col0, #T_0c66e_row1_col1, #T_0c66e_row1_col2, #T_0c66e_row1_col3, #T_0c66e_row1_col4, #T_0c66e_row1_col5, #T_0c66e_row1_col6, #T_0c66e_row1_col7, #T_0c66e_row1_col9, #T_0c66e_row1_col10, #T_0c66e_row1_col11, #T_0c66e_row1_col12, #T_0c66e_row1_col13, #T_0c66e_row2_col0, #T_0c66e_row2_col1, #T_0c66e_row2_col2, #T_0c66e_row2_col3, #T_0c66e_row2_col4, #T_0c66e_row2_col5, #T_0c66e_row2_col6, #T_0c66e_row2_col7, #T_0c66e_row2_col9, #T_0c66e_row2_col10, #T_0c66e_row2_col11, #T_0c66e_row2_col12, #T_0c66e_row2_col13, #T_0c66e_row3_col0, #T_0c66e_row3_col1, #T_0c66e_row3_col2, #T_0c66e_row3_col3, #T_0c66e_row3_col4, #T_0c66e_row3_col5, #T_0c66e_row3_col6, #T_0c66e_row3_col7, #T_0c66e_row3_col9, #T_0c66e_row3_col10, #T_0c66e_row3_col11, #T_0c66e_row3_col12, #T_0c66e_row3_col13, #T_0c66e_row4_col0, #T_0c66e_row4_col1, #T_0c66e_row4_col2, #T_0c66e_row4_col3, #T_0c66e_row4_col4, #T_0c66e_row4_col5, #T_0c66e_row4_col6, #T_0c66e_row4_col7, #T_0c66e_row4_col9, #T_0c66e_row4_col10, #T_0c66e_row4_col11, #T_0c66e_row4_col12, #T_0c66e_row4_col13, #T_0c66e_row5_col0, #T_0c66e_row5_col1, #T_0c66e_row5_col2, #T_0c66e_row5_col3, #T_0c66e_row5_col4, #T_0c66e_row5_col5, #T_0c66e_row5_col6, #T_0c66e_row5_col7, #T_0c66e_row5_col9, #T_0c66e_row5_col10, #T_0c66e_row5_col11, #T_0c66e_row5_col12, #T_0c66e_row5_col13, #T_0c66e_row6_col0, #T_0c66e_row6_col1, #T_0c66e_row6_col2, #T_0c66e_row6_col3, #T_0c66e_row6_col4, #T_0c66e_row6_col5, #T_0c66e_row6_col6, #T_0c66e_row6_col7, #T_0c66e_row6_col9, #T_0c66e_row6_col10, #T_0c66e_row6_col11, #T_0c66e_row6_col12, #T_0c66e_row6_col13, #T_0c66e_row7_col0, #T_0c66e_row7_col1, #T_0c66e_row7_col2, #T_0c66e_row7_col3, #T_0c66e_row7_col4, #T_0c66e_row7_col5, #T_0c66e_row7_col6, #T_0c66e_row7_col7, #T_0c66e_row7_col9, #T_0c66e_row7_col10, #T_0c66e_row7_col11, #T_0c66e_row7_col12, #T_0c66e_row7_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_0c66e_row0_col8 {
#   border: 1px solid black;
#   background-color: white;
#   border-top: 5px solid red;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_0c66e_row1_col8, #T_0c66e_row3_col8, #T_0c66e_row4_col8, #T_0c66e_row6_col8 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_0c66e_row2_col8 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: lightgreen;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_0c66e_row5_col8 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: rgb(212,175,55);
#   border-left: 5px solid red;
#   border-right: 5px solid red;
# }
# #T_0c66e_row7_col8 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: 5px solid red;
#   border-right: 5px solid red;
#   border-bottom: 5px solid red;
# }
# #T_0c66e_row8_col8 {
#   border: 5px solid red;
# }
# </style>
# <table id="T_0c66e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c66e_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_0c66e_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_0c66e_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_0c66e_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_0c66e_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_0c66e_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_0c66e_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_0c66e_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_0c66e_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_0c66e_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_0c66e_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_0c66e_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_0c66e_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_0c66e_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_0c66e_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_0c66e_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_0c66e_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_0c66e_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_0c66e_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_0c66e_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c66e_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_0c66e_row0_col0" class="data row0 col0" ></td>
#       <td id="T_0c66e_row0_col1" class="data row0 col1" ></td>
#       <td id="T_0c66e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_0c66e_row0_col3" class="data row0 col3" ></td>
#       <td id="T_0c66e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_0c66e_row0_col5" class="data row0 col5" ></td>
#       <td id="T_0c66e_row0_col6" class="data row0 col6" ></td>
#       <td id="T_0c66e_row0_col7" class="data row0 col7" ></td>
#       <td id="T_0c66e_row0_col8" class="data row0 col8" ></td>
#       <td id="T_0c66e_row0_col9" class="data row0 col9" ></td>
#       <td id="T_0c66e_row0_col10" class="data row0 col10" ></td>
#       <td id="T_0c66e_row0_col11" class="data row0 col11" ></td>
#       <td id="T_0c66e_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0c66e_row0_col13" class="data row0 col13" ></td>
#       <td id="T_0c66e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_0c66e_row0_col15" class="data row0 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0c66e_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_0c66e_row1_col0" class="data row1 col0" ></td>
#       <td id="T_0c66e_row1_col1" class="data row1 col1" ></td>
#       <td id="T_0c66e_row1_col2" class="data row1 col2" ></td>
#       <td id="T_0c66e_row1_col3" class="data row1 col3" ></td>
#       <td id="T_0c66e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_0c66e_row1_col5" class="data row1 col5" ></td>
#       <td id="T_0c66e_row1_col6" class="data row1 col6" ></td>
#       <td id="T_0c66e_row1_col7" class="data row1 col7" ></td>
#       <td id="T_0c66e_row1_col8" class="data row1 col8" ></td>
#       <td id="T_0c66e_row1_col9" class="data row1 col9" ></td>
#       <td id="T_0c66e_row1_col10" class="data row1 col10" ></td>
#       <td id="T_0c66e_row1_col11" class="data row1 col11" ></td>
#       <td id="T_0c66e_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0c66e_row1_col13" class="data row1 col13" ></td>
#       <td id="T_0c66e_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_0c66e_row1_col15" class="data row1 c

# %% [markdown]
# ## Part 2, fixing UNSAT models
#
# Now that we know _why_ a model is UNSAT, we need to fix it.
#
# In the presentation, several techniques are shown for doing so.
#
# Below, you can find some skeleton code to play around with feasibiliy restoration techniques

# %%
model, nurse_view = factory.get_decision_model()
model.solve()
# Out:
# False

# %%
from cpmpy.tools.explain import mss_opt, mcs_opt

def get_weight(cons):
    if "cover" in str(cons):
        return 10
    return 1

# find Max-CSP solution
optimal_subset = mss_opt(model.constraints, hard=[],weights=[get_weight(c) for c in model.constraints])
mcs = set(model.constraints) - set(optimal_subset)
print("Found solution after dropping these constraints:")
for i,c in enumerate(mcs):
    print(f"{i}.", c)
# Out:
# Found solution after dropping these constraints:
# 0. Robert has a day off on Tue 2
# 1. Kevin should work at most 1 weekends
# 2. Robert should have at least 2 consecutive days off
# 3. Kristen has a day off on Tue 1
# 4. Richard requests not to work shift D on Tue 2
# 5. William should work at most 1 weekends
# 6. Kristen should work at most 1 weekends
# 7. Jonathan should work at most 1 weekends

# %%
assert cp.Model(optimal_subset).solve() is True
visualize(nurse_view.value(), factory)
visualize_constraints(mcs, nurse_view, factory, do_clear=False)
# Out:
# <style type="text/css">
# #T_5f919 .data {
#   text-align: center;
# }
# #T_5f919 .col_heading {
#   text-align: center;
# }
# #T_5f919 .col7 {
#   border-left: 2px solid black;
# }
# #T_5f919_row0_col0, #T_5f919_row0_col6, #T_5f919_row0_col7, #T_5f919_row0_col12, #T_5f919_row0_col13, #T_5f919_row1_col5, #T_5f919_row1_col6, #T_5f919_row1_col9, #T_5f919_row1_col10, #T_5f919_row1_col11, #T_5f919_row2_col10, #T_5f919_row2_col11, #T_5f919_row2_col12, #T_5f919_row2_col13, #T_5f919_row3_col2, #T_5f919_row3_col3, #T_5f919_row3_col4, #T_5f919_row3_col10, #T_5f919_row3_col11, #T_5f919_row4_col0, #T_5f919_row4_col3, #T_5f919_row4_col4, #T_5f919_row4_col9, #T_5f919_row4_col10, #T_5f919_row5_col5, #T_5f919_row5_col6, #T_5f919_row5_col9, #T_5f919_row5_col10, #T_5f919_row5_col13, #T_5f919_row6_col0, #T_5f919_row6_col3, #T_5f919_row6_col4, #T_5f919_row6_col9, #T_5f919_row6_col10, #T_5f919_row7_col1, #T_5f919_row7_col2, #T_5f919_row7_col3, #T_5f919_row7_col7, #T_5f919_row7_col8 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# #T_5f919_row0_col1, #T_5f919_row0_col2, #T_5f919_row0_col3, #T_5f919_row0_col4, #T_5f919_row0_col5, #T_5f919_row0_col8, #T_5f919_row0_col9, #T_5f919_row0_col10, #T_5f919_row0_col11, #T_5f919_row1_col0, #T_5f919_row1_col1, #T_5f919_row1_col2, #T_5f919_row1_col3, #T_5f919_row1_col4, #T_5f919_row1_col7, #T_5f919_row1_col8, #T_5f919_row1_col12, #T_5f919_row1_col13, #T_5f919_row2_col0, #T_5f919_row2_col1, #T_5f919_row2_col2, #T_5f919_row2_col3, #T_5f919_row2_col4, #T_5f919_row2_col7, #T_5f919_row2_col9, #T_5f919_row3_col0, #T_5f919_row3_col1, #T_5f919_row3_col7, #T_5f919_row3_col8, #T_5f919_row3_col9, #T_5f919_row4_col1, #T_5f919_row4_col2, #T_5f919_row4_col7, #T_5f919_row4_col8, #T_5f919_row4_col11, #T_5f919_row5_col0, #T_5f919_row5_col1, #T_5f919_row5_col2, #T_5f919_row5_col3, #T_5f919_row5_col4, #T_5f919_row5_col7, #T_5f919_row5_col11, #T_5f919_row5_col12, #T_5f919_row6_col2, #T_5f919_row6_col7, #T_5f919_row6_col8, #T_5f919_row6_col11, #T_5f919_row7_col0, #T_5f919_row7_col4, #T_5f919_row7_col9, #T_5f919_row7_col10, #T_5f919_row7_col11 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_5f919_row2_col5 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   border-left: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_5f919_row2_col6 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-right: 5px dotted lightgreen;
#   border-top: 5px dotted lightgreen;
#   border-bottom: 5px dotted lightgreen;
# }
# #T_5f919_row2_col8, #T_5f919_row6_col1 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   background-color: lightgreen;
# }
# #T_5f919_row3_col5, #T_5f919_row3_col12, #T_5f919_row4_col5, #T_5f919_row4_col12, #T_5f919_row6_col5, #T_5f919_row6_col12, #T_5f919_row7_col5, #T_5f919_row7_col12 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-left: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_5f919_row3_col6, #T_5f919_row3_col13, #T_5f919_row4_col6, #T_5f919_row4_col13, #T_5f919_row6_col6, #T_5f919_row7_col6, #T_5f919_row7_col13 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# #T_5f919_row5_col8 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
#   background-color: rgb(212,175,55);
# }
# #T_5f919_row6_col13 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
#   border-right: 5px solid indigo;
#   border-top: 5px solid indigo;
#   border-bottom: 5px solid indigo;
# }
# </style>
# <table id="T_5f919">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f919_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_5f919_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_5f919_level0_col14" class="col_heading level0 col14" >#Shifts</th>
#       <th id="T_5f919_level0_col15" class="col_heading level0 col15" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_5f919_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_5f919_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_5f919_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_5f919_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_5f919_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_5f919_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_5f919_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_5f919_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_5f919_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_5f919_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_5f919_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_5f919_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_5f919_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_5f919_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_5f919_level1_col14" class="col_heading level1 col14" >D</th>
#       <th id="T_5f919_level1_col15" class="col_heading level1 col15" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f919_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_5f919_row0_col0" class="data row0 col0" >F</td>
#       <td id="T_5f919_row0_col1" class="data row0 col1" >D</td>
#       <td id="T_5f919_row0_col2" class="data row0 col2" >D</td>
#       <td id="T_5f919_row0_col3" class="data row0 col3" >D</td>
#       <td id="T_5f919_row0_col4" class="data row0 col4" >D</td>
#       <td id="T_5f919_row0_col5" class="data row0 col5" >D</td>
#       <td id="T_5f919_row0_col6" class="data row0 col6" >F</td>
#       <td id="T_5f919_row0_col7" class="data row0 col7" >F</td>
#       <td id="T_5f919_row0_col8" class="data row0 col8" >D</td>
#       <td id="T_5f919_row0_col9" class="data row0 col9" >D</td>
#       <td id="T_5f919_row0_col10" class="data row0 col10" >D</td>
#       <td id="T_5f919_row0_col11" class="data row0 col11" >D</td>
#       <td id="T_5f919_row0_col12" class="data row0 col12" >F</td>
#       <td id="T_5f919_row0_col13" class="data row0 col13" >F</td>
#       <td id="T_5f919_row0_col14" class="data row0 col14" >9</td>
#       <td id="T_5f919_row0_col15" class="data row0 col15" >4320</td>
#     </tr>
#     <tr>
#       <th id="T_5f919_level0_row1" class="row_heading level0 row1" >Katherine</th>
#       <td id="T_5f919_row1_col0" class="data row1 col0" >D</td>
#       <td id="T_5f919_row1_col1" class="data row1 col1" >D</td>
#       <td id="T_5f919_row1_col2" class="data row1 col2" >D</td>
#       <td id="T_5f919_row1_col3" class="data row1 col3" >D</td>
#       <td id="T_5f919_row1_col4" class="data row1 col4" >D</td>
#       <td id="T_5f919_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_5f919_row1_col6" class="data row1 col6" >F</td>
#       <td id="T_5f919_row1_col7" class="data row1 col7" >D</td>
#       <td id="T_5f919_row1_col8" class="data row1 col8" >D</td>
#       <td id="T_5f919_row1

# %% [markdown]
# ### Slack-based relaxation
#
# Apart from dropping constraints, they can also be _relaxed_ when numeric

# %%
model, nurse_view, slack_under, slack_over = factory.get_slack_model()  # CMPpy Model

# TODO..
