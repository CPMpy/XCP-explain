# %%
# %load_ext autoreload
# %autoreload 2
"""
    Some imports used throughout the notebook
"""
import time

from visualize import *

from cpmpy.transformations.normalize import toplevel_list
from factory import *
from read_data import get_data
from IPython.display import clear_output


import numpy as np
np.set_printoptions(linewidth=90)
# preload solvers
from cpmpy import SolverLookup
names = SolverLookup.solvernames()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-06-03

# %% [markdown]
# ## Hands-on causal explanations
#
# In this notebook, you will get experience with computing causal explanations.
#
# We focus on explaining unsatisfiability by means of extracting a MUS.
#
#
#
# <img src="img/mus.png" width="20%" align="right" style="margin:50px;">
#
# Trim model to minimal set of constraints
#
# ... minimize cognitive burden for user

# %%
instance = "Benchmarks/Instance2.txt"
data = get_data(instance)
factory = NurseSchedulingFactory(data)

# %% [markdown]
# Let's have a look at the instance and its (optimal) solution.

# %%
data.staff[["name", "MaxShifts","MaxWeekends"]]
# Out:
#          name  MaxShifts  MaxWeekends
# 0       Megan  E=14|L=14            1
# 1   Katherine  E=14|L=14            1
# 2      Robert  E=14|L=14            1
# 3    Jonathan   E=14|L=0            1
# 4     William   E=0|L=14            1
# 5     Richard  E=14|L=14            1
# 6     Kristen  E=14|L=14            1
# 7       Kevin  E=14|L=14            1
# 8      Thomas  E=14|L=14            1
# 9      Brandy  E=14|L=14            1
# 10    Rebecca   E=0|L=14            1
# 11       Juan   E=0|L=14            1
# 12    Katelyn  E=14|L=14            1
# 13  Christine  E=14|L=14            1

# %%
print(f"Planning for {data.horizon} days")
# Out:
# Planning for 14 days

# %%
import random

# %%
model, nurse_view = factory.get_optimization_model()
random.shuffle(model.constraints)
assert model.solve(solver="ortools") # you can try different solvers here!


print(model.status())
print("Total penalty:", model.objective_value())
visualize(nurse_view.value(), factory)
# Out:
# ExitStatus.OPTIMAL (1.859007 seconds)
# Total penalty: 828
# <style type="text/css">
# #T_393c3 .data {
#   text-align: center;
# }
# #T_393c3 .col_heading {
#   text-align: center;
# }
# #T_393c3 .col7 {
#   border-left: 2px solid black;
# }
# #T_393c3_row0_col0, #T_393c3_row0_col1, #T_393c3_row1_col3, #T_393c3_row1_col4, #T_393c3_row1_col7, #T_393c3_row1_col8, #T_393c3_row1_col9, #T_393c3_row1_col12, #T_393c3_row1_col13, #T_393c3_row2_col3, #T_393c3_row2_col4, #T_393c3_row2_col5, #T_393c3_row2_col9, #T_393c3_row2_col10, #T_393c3_row2_col11, #T_393c3_row3_col0, #T_393c3_row3_col1, #T_393c3_row3_col2, #T_393c3_row3_col3, #T_393c3_row3_col4, #T_393c3_row3_col8, #T_393c3_row3_col9, #T_393c3_row3_col10, #T_393c3_row3_col13, #T_393c3_row6_col0, #T_393c3_row6_col1, #T_393c3_row6_col2, #T_393c3_row6_col3, #T_393c3_row6_col10, #T_393c3_row6_col11, #T_393c3_row6_col12, #T_393c3_row7_col0, #T_393c3_row7_col1, #T_393c3_row7_col5, #T_393c3_row7_col6, #T_393c3_row7_col7, #T_393c3_row7_col8, #T_393c3_row8_col7, #T_393c3_row8_col12, #T_393c3_row9_col9, #T_393c3_row9_col10, #T_393c3_row12_col3, #T_393c3_row13_col2, #T_393c3_row13_col8, #T_393c3_row13_col12, #T_393c3_row13_col13 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_393c3_row0_col2, #T_393c3_row0_col5, #T_393c3_row0_col6, #T_393c3_row0_col7, #T_393c3_row0_col8, #T_393c3_row0_col9, #T_393c3_row1_col0, #T_393c3_row2_col0, #T_393c3_row2_col6, #T_393c3_row4_col0, #T_393c3_row4_col3, #T_393c3_row4_col4, #T_393c3_row4_col5, #T_393c3_row4_col6, #T_393c3_row4_col7, #T_393c3_row4_col10, #T_393c3_row4_col11, #T_393c3_row5_col2, #T_393c3_row5_col3, #T_393c3_row5_col4, #T_393c3_row5_col5, #T_393c3_row5_col6, #T_393c3_row5_col9, #T_393c3_row5_col10, #T_393c3_row5_col11, #T_393c3_row6_col4, #T_393c3_row6_col13, #T_393c3_row7_col2, #T_393c3_row7_col9, #T_393c3_row8_col1, #T_393c3_row8_col2, #T_393c3_row8_col3, #T_393c3_row8_col4, #T_393c3_row8_col8, #T_393c3_row8_col9, #T_393c3_row8_col13, #T_393c3_row9_col0, #T_393c3_row9_col1, #T_393c3_row9_col2, #T_393c3_row9_col3, #T_393c3_row9_col11, #T_393c3_row9_col12, #T_393c3_row9_col13, #T_393c3_row10_col2, #T_393c3_row10_col8, #T_393c3_row10_col12, #T_393c3_row10_col13, #T_393c3_row11_col8, #T_393c3_row11_col10, #T_393c3_row11_col12, #T_393c3_row11_col13, #T_393c3_row12_col1, #T_393c3_row12_col5, #T_393c3_row12_col6 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
# }
# #T_393c3_row0_col3, #T_393c3_row0_col4, #T_393c3_row0_col10, #T_393c3_row0_col11, #T_393c3_row0_col12, #T_393c3_row0_col13, #T_393c3_row1_col1, #T_393c3_row1_col2, #T_393c3_row1_col5, #T_393c3_row1_col6, #T_393c3_row1_col10, #T_393c3_row1_col11, #T_393c3_row2_col1, #T_393c3_row2_col2, #T_393c3_row2_col7, #T_393c3_row2_col8, #T_393c3_row2_col12, #T_393c3_row2_col13, #T_393c3_row3_col5, #T_393c3_row3_col6, #T_393c3_row3_col7, #T_393c3_row3_col11, #T_393c3_row3_col12, #T_393c3_row4_col1, #T_393c3_row4_col2, #T_393c3_row4_col8, #T_393c3_row4_col9, #T_393c3_row4_col12, #T_393c3_row4_col13, #T_393c3_row5_col0, #T_393c3_row5_col1, #T_393c3_row5_col7, #T_393c3_row5_col8, #T_393c3_row5_col12, #T_393c3_row5_col13, #T_393c3_row6_col5, #T_393c3_row6_col6, #T_393c3_row6_col7, #T_393c3_row6_col8, #T_393c3_row6_col9, #T_393c3_row7_col3, #T_393c3_row7_col4, #T_393c3_row7_col10, #T_393c3_row7_col11, #T_393c3_row7_col12, #T_393c3_row7_col13, #T_393c3_row8_col0, #T_393c3_row8_col5, #T_393c3_row8_col6, #T_393c3_row8_col10, #T_393c3_row8_col11, #T_393c3_row9_col4, #T_393c3_row9_col5, #T_393c3_row9_col6, #T_393c3_row9_col7, #T_393c3_row9_col8, #T_393c3_row10_col0, #T_393c3_row10_col1, #T_393c3_row10_col3, #T_393c3_row10_col4, #T_393c3_row10_col5, #T_393c3_row10_col6, #T_393c3_row10_col7, #T_393c3_row10_col9, #T_393c3_row10_col10, #T_393c3_row10_col11, #T_393c3_row11_col0, #T_393c3_row11_col1, #T_393c3_row11_col2, #T_393c3_row11_col3, #T_393c3_row11_col4, #T_393c3_row11_col5, #T_393c3_row11_col6, #T_393c3_row11_col7, #T_393c3_row11_col9, #T_393c3_row11_col11, #T_393c3_row12_col0, #T_393c3_row12_col2, #T_393c3_row12_col4, #T_393c3_row12_col7, #T_393c3_row12_col8, #T_393c3_row12_col9, #T_393c3_row12_col10, #T_393c3_row12_col11, #T_393c3_row12_col12, #T_393c3_row12_col13, #T_393c3_row13_col0, #T_393c3_row13_col1, #T_393c3_row13_col3, #T_393c3_row13_col4, #T_393c3_row13_col5, #T_393c3_row13_col6, #T_393c3_row13_col7, #T_393c3_row13_col9, #T_393c3_row13_col10, #T_393c3_row13_col11 {
#   border: 1px solid black;
#   background-color: rgb(141,211,199);
# }
# </style>
# <table id="T_393c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_393c3_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_393c3_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_393c3_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_393c3_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_393c3_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_393c3_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_393c3_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_393c3_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_393c3_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_393c3_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_393c3_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_393c3_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_393c3_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_393c3_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_393c3_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_393c3_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_393c3_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_393c3_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_393c3_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_393c3_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_393c3_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_393c3_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_393c3_row0_col0" class="data row0 col0" >E</td>
#       <td id="T_393c3_row0_col1" class="data row0 col1" >E</td>
#       <td id="T_393c3_row0_col2" class="data row0 col2" >L</td>
#       <td id="T_393c3_row0_col3" class="data row0 col3" >F</td>
#       <td id="T_393c3_row0_col4" class="data row0 col4" >F</td>
#       <td id="T_393c3_row0_col5" class="data row0 col5" >L</td>
#       <td id="T_393c3_row0_col6" class="data row0 col6" >L</td>
#       <td id="T_393c3_row0_col7" class="data row0 col7" >L</td>
#       <td id="T_393c3_row0_col8" class="data row0 col8" >L</td>
#       <td id="T_393c3_row0_col9" class="data row0 col9" >L</td>
#       <td id="T_393c3_row0_col10" class="data row0 col10" >F</td>
#       <td id="T_393c3_row0_col11" class="data row0 col11" >F</td>
#       <td id="T_393c3_row0_col12" class="data row0 col12" >F</td>
#       <td id="T_393c3_ro

# %%
requests, _ = factory.shift_on_requests(formulation="hard")

denied_requests = [req for req in requests if req.value() is False]
print("The following requests were denied:")
for req in denied_requests:
    print("-", req)

visualize_constraints(denied_requests, nurse_view, factory, do_clear=False)
# Out:
# The following requests were denied:
# - Katherine requests to work shift E on Thu 2
# - Robert requests to work shift E on Tue 2
# - William requests to work shift L on Sat 2
# - William requests to work shift L on Sun 2
# - Rebecca requests to work shift L on Mon 2
# - Rebecca requests to work shift L on Wed 2
# - Juan requests to work shift L on Thu 1
# - Juan requests to work shift L on Fri 1
# - Juan requests to work shift L on Fri 2
# - Katelyn requests to work shift L on Thu 1
# - Katelyn requests to work shift L on Fri 1
# - Katelyn requests to work shift L on Mon 2
# - Christine requests to work shift E on Mon 1
# - Christine requests to work shift E on Tue 1
# - Christine requests to work shift E on Wed 2
# - Christine requests to work shift E on Thu 2
# <style type="text/css">
# #T_258c8 .data {
#   text-align: center;
# }
# #T_258c8 .col_heading {
#   text-align: center;
# }
# #T_258c8 .col7 {
#   border-left: 2px solid black;
# }
# #T_258c8_row0_col0, #T_258c8_row0_col1, #T_258c8_row1_col3, #T_258c8_row1_col4, #T_258c8_row1_col7, #T_258c8_row1_col8, #T_258c8_row1_col9, #T_258c8_row1_col12, #T_258c8_row1_col13, #T_258c8_row2_col3, #T_258c8_row2_col4, #T_258c8_row2_col5, #T_258c8_row2_col9, #T_258c8_row2_col10, #T_258c8_row2_col11, #T_258c8_row3_col0, #T_258c8_row3_col1, #T_258c8_row3_col2, #T_258c8_row3_col3, #T_258c8_row3_col4, #T_258c8_row3_col8, #T_258c8_row3_col9, #T_258c8_row3_col10, #T_258c8_row3_col13, #T_258c8_row6_col0, #T_258c8_row6_col1, #T_258c8_row6_col2, #T_258c8_row6_col3, #T_258c8_row6_col10, #T_258c8_row6_col11, #T_258c8_row6_col12, #T_258c8_row7_col0, #T_258c8_row7_col1, #T_258c8_row7_col5, #T_258c8_row7_col6, #T_258c8_row7_col7, #T_258c8_row7_col8, #T_258c8_row8_col7, #T_258c8_row8_col12, #T_258c8_row9_col9, #T_258c8_row9_col10, #T_258c8_row13_col2, #T_258c8_row13_col8, #T_258c8_row13_col12, #T_258c8_row13_col13 {
#   border: 1px solid black;
#   background-color: rgb(255,255,179);
# }
# #T_258c8_row0_col2, #T_258c8_row0_col5, #T_258c8_row0_col6, #T_258c8_row0_col7, #T_258c8_row0_col8, #T_258c8_row0_col9, #T_258c8_row1_col0, #T_258c8_row2_col0, #T_258c8_row2_col6, #T_258c8_row4_col0, #T_258c8_row4_col3, #T_258c8_row4_col4, #T_258c8_row4_col5, #T_258c8_row4_col6, #T_258c8_row4_col7, #T_258c8_row4_col10, #T_258c8_row4_col11, #T_258c8_row5_col2, #T_258c8_row5_col3, #T_258c8_row5_col4, #T_258c8_row5_col5, #T_258c8_row5_col6, #T_258c8_row5_col9, #T_258c8_row5_col10, #T_258c8_row5_col11, #T_258c8_row6_col4, #T_258c8_row6_col13, #T_258c8_row7_col2, #T_258c8_row7_col9, #T_258c8_row8_col1, #T_258c8_row8_col2, #T_258c8_row8_col3, #T_258c8_row8_col4, #T_258c8_row8_col8, #T_258c8_row8_col9, #T_258c8_row8_col13, #T_258c8_row9_col0, #T_258c8_row9_col1, #T_258c8_row9_col2, #T_258c8_row9_col3, #T_258c8_row9_col11, #T_258c8_row9_col12, #T_258c8_row9_col13, #T_258c8_row10_col2, #T_258c8_row10_col8, #T_258c8_row10_col12, #T_258c8_row10_col13, #T_258c8_row11_col8, #T_258c8_row11_col10, #T_258c8_row11_col12, #T_258c8_row11_col13, #T_258c8_row12_col1, #T_258c8_row12_col5, #T_258c8_row12_col6 {
#   border: 1px solid black;
#   background-color: rgb(190,186,218);
# }
level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_258c8_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_258c8_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_258c8_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_258c8_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_258c8_row0_col0" class="data row0 col0" >E</td>
#       <td id="T_258c8_row0_col1" class="data row0 col1" >E</td>
#       <td id="T_258c8_row0_col2" class="data row0 col2" >L</td>
#       <td id="T_258c8_row0_col3" class="data row0 col3" >F</td>
#       <td id="T_258c8_row0_col4" class="data row0 col4" >F</td>
#       <td id="T_258c8_row0_col5" class="data row0 col5" >L</td>
#       <td id="T_258c8_row0_col6" class="data row0 col6" >L</td>
#       <td id="T_258c8_row0_col7" class="data row0 col7" >L</td>
#       <td id="T_258c8_row0_col8" class="data row0 col8" >L</td>
#       <td id="T_258c8_row0_col9" class="data row0 col9" >L</td>
#       <t

# %%
# try it yourself!

# requests, _ = factory.shift_off_requests(formulation="hard")
# cover_constraints, _ = factory.cover(formulation="hard")

# TODO: find out which are not satisfied, and visualize!

# %% [markdown]
# ## Deductive explanations
#
# In the remainder of this notebook, we will explore different ways of explaining unsatisfiabily of the instance.

# %%
model, nurse_view = factory.get_decision_model()
model.solve()
# Out:
# False

# %%
from cpmpy.tools.explain import mus

t0 = time.time()
conflict = mus(model.constraints) # try different solvers here!
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 3 in 1.04s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - William should work at most 1 weekends
# - William requests to work shift L on Sat 1
# - William requests to work shift L on Sat 2
# <style type="text/css">
# #T_f9882 .data {
#   text-align: center;
# }
# #T_f9882 .col_heading {
#   text-align: center;
# }
# #T_f9882 .col7 {
#   border-left: 2px solid black;
# }
# #T_f9882_row0_col0, #T_f9882_row0_col1, #T_f9882_row0_col2, #T_f9882_row0_col3, #T_f9882_row0_col4, #T_f9882_row0_col5, #T_f9882_row0_col6, #T_f9882_row0_col7, #T_f9882_row0_col8, #T_f9882_row0_col9, #T_f9882_row0_col10, #T_f9882_row0_col11, #T_f9882_row0_col12, #T_f9882_row0_col13, #T_f9882_row1_col0, #T_f9882_row1_col1, #T_f9882_row1_col2, #T_f9882_row1_col3, #T_f9882_row1_col4, #T_f9882_row1_col5, #T_f9882_row1_col6, #T_f9882_row1_col7, #T_f9882_row1_col8, #T_f9882_row1_col9, #T_f9882_row1_col10, #T_f9882_row1_col11, #T_f9882_row1_col12, #T_f9882_row1_col13, #T_f9882_row2_col0, #T_f9882_row2_col1, #T_f9882_row2_col2, #T_f9882_row2_col3, #T_f9882_row2_col4, #T_f9882_row2_col5, #T_f9882_row2_col6, #T_f9882_row2_col7, #T_f9882_row2_col8, #T_f9882_row2_col9, #T_f9882_row2_col10, #T_f9882_row2_col11, #T_f9882_row2_col12, #T_f9882_row2_col13, #T_f9882_row3_col0, #T_f9882_row3_col1, #T_f9882_row3_col2, #T_f9882_row3_col3, #T_f9882_row3_col4, #T_f9882_row3_col5, #T_f9882_row3_col6, #T_f9882_row3_col
12_col5, #T_f9882_row12_col6, #T_f9882_row12_col7, #T_f9882_row12_col8, #T_f9882_row12_col9, #T_f9882_row12_col10, #T_f9882_row12_col11, #T_f9882_row12_col12, #T_f9882_row12_col13, #T_f9882_row13_col0, #T_f9882_row13_col1, #T_f9882_row13_col2, #T_f9882_row13_col3, #T_f9882_row13_col4, #T_f9882_row13_col5, #T_f9882_row13_col6, #T_f9882_row13_col7, #T_f9882_row13_col8, #T_f9882_row13_col9, #T_f9882_row13_col10, #T_f9882_row13_col11, #T_f9882_row13_col12, #T_f9882_row13_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_f9882_row4_col5, #T_f9882_row4_col12 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: solid indigo;
#   border-top: solid indigo;
#   border-bottom: solid indigo;
#   background-color: rgb(183, 119, 41);
# }
# #T_f9882_row4_col6, #T_f9882_row4_col13 {
#   border: 1px solid black;
#   background-color: white;
#   border-right: solid indigo;
#   border-top: solid indigo;
#   border-bottom: solid indigo;
# }
# </style>
# <table id="T_f9882">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9882_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_f9882_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_f9882_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_f9882_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_f9882_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_f9882_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_f9882_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_f9882_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_f9882_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_f9882_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_f9882_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_f9882_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_f9882_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_f9882_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_f9882_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_f9882_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_f9882_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_f9882_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_f9882_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_f9882_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_f9882_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9882_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_f9882_row0_col0" class="data row0 col0" ></td>
#       <td id="T_f9882_row0_col1" class="data row0 col1" ></td>
#       <td id="T_f9882_row0_col2" class="data row0 col2" ></td>
#       <td id="T_f9882_row0_col3" class="data row0 col3" ></td>
#       <td id="T_f9882_row0_col4" class="data row0 col4" ></td>
#       <td id="T_f9882_row0_col5" class="data row0 col5" ></td>
#       <td id="T_f9882_row0_col6" class="data row0 col6" ></td>
#       <td id="T_f9882_row0_col7" class="data row0 col7" ></td>
#       <td id="T_f9882_row0_col8" class="data row0 col8" ></td>
#       <td id="T_f9882_row0_col9" class="data row0 col9" ></td>
#       <td id="T_f9882_row0_col10" class="data row

# %% [markdown]
# Now, let's influence the MUS we would like to find.
#
# We can chose from QuickXplain [1] or Optimal MUS (OUS) [2]
#
# **QuickXplain** takes as input a total ordering of constraints, and returns a lexicographically minimal MUS.
# The algorithm is build up as a divide-and-conquer approach, and therefore has a good average complexity.
#
# **OUS** takes as input a weight for each constraint, and finds a **optimal** MUS. While this optimality guarantee is sometimes required, it comes at a penalty of longer computation times, as you will notice here!

# %%
# QuickXplain first
from cpmpy.tools.explain import quickxplain


def get_weight(cons):
    if "William" in str(cons): # Find a different MUS than the previous
        return 2 
    return 1

ordered = sorted(model.constraints, key=get_weight)
conflict = quickxplain(ordered)
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Found conflict of size 6 in 5.12s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Juan cannot work more than 2160min
# - Juan requests to work shift L on Thu 1
# - Juan requests to work shift L on Fri 1
# - Juan requests to work shift L on Thu 2
# - Juan requests to work shift L on Fri 2
# - Juan requests to work shift L on Sat 2
# <style type="text/css">
# #T_ac128 .data {
#   text-align: center;
# }
# #T_ac128 .col_heading {
#   text-align: center;
# }
# #T_ac128 .col7 {
#   border-left: 2px solid black;
# }
# #T_ac128_row0_col0, #T_ac128_row0_col1, #T_ac128_row0_col2, #T_ac128_row0_col3, #T_ac128_row0_col4, #T_ac128_row0_col5, #T_ac128_row0_col6, #T_ac128_row0_col7, #T_ac128_row0_col8, #T_ac128_row0_col9, #T_ac128_row0_col10, #T_ac128_row0_col11, #T_ac128_row0_col12, #T_ac128_row0_col13, #T_ac128_row1_col0, #T_ac128_row1_col1, #T_ac128_row1_col2, #T_ac128_row1_col3, #T_ac128_row1_col4, #T_ac128_row1_col5, #T_ac128_row1_col6, #T_ac128_row1_col7, #T_ac128_row1_col8, #T_ac128_row1_col9, #T_ac128_row1_col10, #T_ac128_row1_col11, #T_ac128_row1_col12, #T_ac128_row1_col13, #T_ac128_row2_col0, #T_ac128_row2_col1, #T_ac128_row2_col2, #T_ac128_row2_col3, #T_ac128_row2_col4, #T_ac128_row2_col5, #T_ac128_row2_col6, #T_ac128_row2_col7, #T_ac128_row2_col8, #T_ac128_row2_col9, #T_ac128_row2_col10, #T_ac128_row2_col11, #T_ac128_row2_col12, #T_ac128_row2_col13, #T_ac128_row3_col0, #T_ac128_row3_col1, #T_ac128_row3_col2, #T_ac128_row3_col3, #T_ac128_row3_col4, #T_ac128_row3_col5, #T_ac128_row3_col6, #T_ac128_row3_col7, #T_ac128_row3_col8, #T_ac128_row3_col9, #T_ac128_row3_col10, #T_ac128_row3_col11, #T_ac128_row3_col12, #T_ac128_row3_col13, #T_ac128_row4_col0, #T_ac128_row4_col1, #T_ac128_row4_col2, #T_ac128_row4_col3, #T_ac128_row4_col4, #T_ac128_row4_col5, #T_ac128_row4_col6, #T_ac128_row4_col7, #T_ac128_row4_col8, #T_ac128_row4_col9, #T_ac128_row4_col10, #T_ac128_row4_col11, #T_ac128_row4_col12, #T_ac128_row4_col13, #T_ac128_row5_col0, #T_ac128_row5_col1, #T_ac128_row5_col2, #T_ac128_row5_col3, #T_ac128_row5_col4, #T_ac128_row5_col5, #T_ac128_row5_col6, #T_ac128_row5_col7, #T_ac128_row5_col8, #T_ac128_row5_col9, #T_ac128_row5_col10, #T_ac128_row5_col11, #T_ac128_row5_col12, #T_ac128_row5_col13, #T_ac128_row6_col0, #T_ac128_row6_col1, #T_ac128_row6_col2, #T_ac128_row6_col3, #T_ac128_row6_col4, #T_ac128_row6_col5, #T_ac128_row6_col6, #T_ac128_row6_col7, #T_ac128_row6_col8, #T_ac128_row6_col9, #T_ac128_row6_col10, #T_ac128_row6_col11, #T_ac128_row6_col12, #T_ac128_row6_col13, #T_ac128_row7_col0, #T_ac128_row7_col1, #T_ac128_row7_col2, #T_ac128_row7_col3, #T_ac128_row7_col4, #T_ac128_row7_col5, #T_ac128_row7_col6, #T_ac128_row7_col7, #T_ac128_row7_col8, #T_ac128_row7_col9, #T_ac128_row7_col10, #T_ac128_row7_col11, #T_ac128_row7_col12, #T_ac128_row7_col13, #T_ac128_row8_col0, #T_ac128_row8_col1, #T_ac128_row8_col2, #T_ac128_row8_col3, #T_ac128_row8_col4, #T_ac128_row8_col5, #T_ac128_row8_col6, #T_ac128_row8_col7, #T_ac128_row8_col8, #T_ac128_row8_col9, #T_ac128_row8_col10, #T_ac128_row8_col11, #T_ac128_row8_col12, #T_ac128_row8_col13, #T_ac128_row9_col0, #T_ac128_row9_col1, #T_ac128_row9_col2, #T_ac128_row9_col3, #T_ac128_row9_col4, #T_ac128_row9_col5, #T_ac128_row9_col6, #T_ac128_row9_col7, #T_ac128_row9_col8, #T_ac128_row9_col9, #T_ac128_row9_col10, #T_ac128_row9_col11, #T_ac128_row9_col12, #T_ac128_row9_col13, #T_ac128_row10_col0, #T_ac128_row10_col1, #T_ac128_row10_col2, #T_ac128_row10_col3, #T_ac128_row10_col4, #T_ac128_row10_col5, #T_ac128_row10_col6, #T_ac128_row10_col7, #T_ac128_row10_col8, #T_ac128_row10_col9, #T_ac128_row10_col10, #T_ac128_row10_col11, #T_ac128_row10_col12, #T_ac128_row10_col13, #T_ac128_row11_col0, #T_ac128_row11_col1, #T_ac128_row11_col2, #T_ac128_row11_col5, #T_ac128_row11_col6, #T_ac128_row11_col7, #T_ac128_row11_col8, #T_ac128_row11_col9, #T_ac128_row11_col13, #T_ac128_row12_col0, #T_ac128_row12_col1, #T_ac128_row12_col2, #T_ac128_row12_col3, #T_ac128_row12_col4, #T_ac128_row12_col5, #T_ac128_row12_col6, #T_ac128_row12_col7, #T_ac128_row12_col8, #T_ac128_row12_col9, #T_ac128_row12_col10, #T_ac128_row12_col11, #T_ac128_row12_col12, #T_ac128_row12_col13, #T_ac128_row13_col0, #T_ac128_row13_col1, #T_ac128_row13_col2, #T_ac128_row13_col3, #T_ac128_row13_col4, #T_ac128_row13_col5, #T_ac128_row13_col6, #T_ac128_row13_col7, #T_ac128_row13_col8, #T_ac128_row13_col9, #T_ac128_row13_col10, #T_ac128_row13_col11, #T_ac128_row13_col12, #T_ac128_row13_col13 {
#   border: 1px solid black;
#   background-color: white;
# }
# #T_ac128_row11_col3, #T_ac128_row11_col4, #T_ac128_row11_col10, #T_ac128_row11_col11, #T_ac128_row11_col12 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: rgb(183, 119, 41);
# }
# #T_ac128_row11_col16 {
#   border: dotted red;
# }
# </style>
# <table id="T_ac128">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac128_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_ac128_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_ac128_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_ac128_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ac128_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_ac128_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_ac128_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_ac128_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_ac128_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_ac128_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_ac128_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_ac128_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_ac128_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_ac128_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_ac128_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_ac128_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_ac128_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_ac128_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_ac128_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_ac128_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_ac128_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac128_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_ac128_row0_col0" class="data row0 col0" ></td>
#       <td id="T_ac128_row0_col1" class="data row0 col1" ></td>
#       <td id="T_ac128_row0_col2" class="data row0 col2" ></td>
#       <td id="T_ac128_row0_col3" class="data row0 col3" ></td>
#       <td id="T_ac128_row0_col4" class="data row0 col4" ></td>
#       <td id="T_ac128_row0_col5" class="data row0 col5" ></td>
#       <td id="T_ac128_row0_col6" class="data row0 col6" ></td>
#       <td id="T_ac128_row0_col7" class="data row0 col7" ></td>
#       <td id="T_ac128_row0_col8" class="data row0 col8" ></td>
#       <td id="T_ac128_row0_col9" class="data row0 col9" ></td>
#       <td id="T_ac128_row0_col10" class="data row0 col10" ></td>
#       <td id="T_ac128_row0_col11" class="data row0 col11" ></td>
#       <td id="T_ac128_row0_col12" class="data row0 col12" ></td>
#       <td id="T_ac128_row0_col13" class="

# %%
# Now find truely OPTIMAL MUSes
## Careful, this takes a while if you are not using Exact!
from cpmpy.tools.explain import optimal_mus

def get_weight(cons):
    if "william" in str(cons).lower():
        return 5
    else:
        return 1
#     return len(str(cons)) # favor constraints with short description


solver = "exact" if "exact" in cp.SolverLookup.solvernames() else "ortools"
print("Using solver", solver)

conflict = optimal_mus(model.constraints, 
                       weights=[get_weight(c) for c in model.constraints],
                       solver=solver,
                       hs_solver="gurobi")
print(f"Found conflict of size {len(conflict)} in {round(time.time()-t0,2)}s")
# Out:
# Using solver exact
# Found conflict of size 4 in 14.56s

# %%
for c in conflict:
    print("-", c)

visualize_constraints(conflict, nurse_view, factory)
# Out:
# - Megan requests to work shift L on Mon 2
# - Rebecca requests to work shift L on Mon 2
# - Katelyn requests to work shift L on Mon 2
# - Shift L on Mon 2 must be covered by 2 nurses out of 14
# <style type="text/css">
# #T_93974 .data {
#   text-align: center;
# }
# #T_93974 .col_heading {
#   text-align: center;
# }
# #T_93974 .col7 {
#   border-left: 2px solid black;
# }
# #T_93974_row0_col0, #T_93974_row0_col1, #T_93974_row0_col2, #T_93974_row0_col3, #T_93974_row0_col4, #T_93974_row0_col5, #T_93974_row0_col6, #T_93974_row0_col8, #T_93974_row0_col9, #T_93974_row0_col10, #T_93974_row0_col11, #T_93974_row0_col12, #T_93974_row0_col13, #T_93974_row1_col0, #T_93974_row1_col1, #T_93974_row1_col2, #T_93974_row1_col3, #T_93974_row1_col4, #T_93974_row1_col5, #T_93974_row1_col6, #T_93974_row1_col8, #T_93974_row1_col9, #T_93974_row1_col10, #T_93974_row1_col11, #T_93974_row1_col12, #T_93974_row1_col13, #T_93974_row2_col0, #T_93974_row2_col1, #T_93974_row2_col2, #T_93974_row2_col3, #T_93974_row2_col4, #T_93974_row2_col5, #T_93974_row2_col6, #T_93974_row2_col8, #T_93974_row2_col9, #T_93974_row2_col10, #T_93974_row2_col11, #T_93974_row2_col12, #T_93974_row2_col13, #T_93974_row3_col0, #T_93974_row3_col1, #T_93974_row3_col2, #T_93974_row3_col3, #T_93974_row3_col4, #
#   border: 1px solid black;
#   background-color: white;
# }
# #T_93974_row0_col7 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: rgb(183, 119, 41);
#   border-top: solid red;
#   border-left: solid red;
#   border-right: solid red;
# }
# #T_93974_row1_col7, #T_93974_row2_col7, #T_93974_row3_col7, #T_93974_row4_col7, #T_93974_row5_col7, #T_93974_row6_col7, #T_93974_row7_col7, #T_93974_row8_col7, #T_93974_row9_col7, #T_93974_row11_col7 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: solid red;
#   border-right: solid red;
# }
# #T_93974_row10_col7, #T_93974_row12_col7 {
#   border: 1px solid black;
#   background-color: white;
#   background-color: rgb(183, 119, 41);
#   border-left: solid red;
#   border-right: solid red;
# }
# #T_93974_row13_col7 {
#   border: 1px solid black;
#   background-color: white;
#   border-left: solid red;
#   border-right: solid red;
#   border-bottom: solid red;
# }
# #T_93974_row15_col7 {
#   border: solid red;
# }
# </style>
# <table id="T_93974">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93974_level0_col0" class="col_heading level0 col0" colspan="7">Week 1</th>
#       <th id="T_93974_level0_col7" class="col_heading level0 col7" colspan="7">Week 2</th>
#       <th id="T_93974_level0_col14" class="col_heading level0 col14" colspan="2">#Shifts</th>
#       <th id="T_93974_level0_col16" class="col_heading level0 col16" >#Minutes</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_93974_level1_col0" class="col_heading level1 col0" >Mon</th>
#       <th id="T_93974_level1_col1" class="col_heading level1 col1" >Tue</th>
#       <th id="T_93974_level1_col2" class="col_heading level1 col2" >Wed</th>
#       <th id="T_93974_level1_col3" class="col_heading level1 col3" >Thu</th>
#       <th id="T_93974_level1_col4" class="col_heading level1 col4" >Fri</th>
#       <th id="T_93974_level1_col5" class="col_heading level1 col5" >Sat</th>
#       <th id="T_93974_level1_col6" class="col_heading level1 col6" >Sun</th>
#       <th id="T_93974_level1_col7" class="col_heading level1 col7" >Mon</th>
#       <th id="T_93974_level1_col8" class="col_heading level1 col8" >Tue</th>
#       <th id="T_93974_level1_col9" class="col_heading level1 col9" >Wed</th>
#       <th id="T_93974_level1_col10" class="col_heading level1 col10" >Thu</th>
#       <th id="T_93974_level1_col11" class="col_heading level1 col11" >Fri</th>
#       <th id="T_93974_level1_col12" class="col_heading level1 col12" >Sat</th>
#       <th id="T_93974_level1_col13" class="col_heading level1 col13" >Sun</th>
#       <th id="T_93974_level1_col14" class="col_heading level1 col14" >E</th>
#       <th id="T_93974_level1_col15" class="col_heading level1 col15" >L</th>
#       <th id="T_93974_level1_col16" class="col_heading level1 col16" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93974_level0_row0" class="row_heading level0 row0" >Megan</th>
#       <td id="T_93974_row0_col0" class="data row0 col0" ></td>
#       <td id="T_93974_row0_col1" class="data row0 col1" ></td>
#       <td id="T_93974_row0_col2" class="data row0 col2" ></td>
#       <td id="T_93974_row0_col3" class="data row0 col3" ></td>
#       <td id="T_93974_row0_col4" class="data row0 col4" ></td>
#       <td id="T_93974_row0_col5" class="data row0 col5" ></td>
#       <td id="T
